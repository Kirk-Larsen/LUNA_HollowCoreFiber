# %%
using Luna

# %%
### reproduce single 15 ft stage broadening to below 10 fs ###
#keep high orders low

# %%
#HCF_ID = 536e-6
#HCF_rad = 268e-6 #HCF_ID/2

HCF_ID = 450e-6
HCF_rad = 225e-6 #HCF_ID/2

output0 = prop_capillary(HCF_rad, 0.375, :Ar, 0.0; λ0=1025e-9, energy=1e-3, τfwhm=190e-15, λlims=(650e-9, 1.5e-6), trange=1e-12)
output1 = prop_capillary(HCF_rad, 0.375, :Ar, 1.0; λ0=1025e-9, energy=1e-3, τfwhm=190e-15, λlims=(650e-9, 1.5e-6), trange=1e-12)
output2 = prop_capillary(HCF_rad, 0.375, :Ar, 2.0; λ0=1025e-9, energy=1e-3, τfwhm=190e-15, λlims=(650e-9, 1.5e-6), trange=1e-12)
output3 = prop_capillary(HCF_rad, 0.375, :Ar, 3.0; λ0=1025e-9, energy=1e-3, τfwhm=190e-15, λlims=(650e-9, 1.5e-6), trange=1e-12)
output4 = prop_capillary(HCF_rad, 0.375, :Ar, 4.0; λ0=1025e-9, energy=1e-3, τfwhm=190e-15, λlims=(650e-9, 1.5e-6), trange=1e-12)
output5 = prop_capillary(HCF_rad, 0.375, :Ar, 5.0; λ0=1025e-9, energy=1e-3, τfwhm=190e-15, λlims=(650e-9, 1.5e-6), trange=1e-12)
# Out:
# ┌ Info: X+Y polarisation not required.
# └ @ Luna.Interface /Users/larsenk/.julia/packages/Luna/An5LJ/src/Interface.jl:353
# ┌ Info: Freq limits 0.20 - 0.46 PHz
# └ @ Luna.Grid /Users/larsenk/.julia/packages/Luna/An5LJ/src/Grid.jl:40
# ┌ Info: Samples needed: 2767.31, samples: 4096, δt = 361.36 as
# └ @ Luna.Grid /Users/larsenk/.julia/packages/Luna/An5LJ/src/Grid.jl:44
# ┌ Info: Requested time window: 1000.0 fs, actual time window: 1480.1 fs
# └ @ Luna.Grid /Users/larsenk/.julia/packages/Luna/An5LJ/src/Grid.jl:46
# ┌ Info: Grid: samples 2048 / 4096, ωmax 4.35e+15 / 8.69e+15
# └ @ Luna.Grid /Users/larsenk/.julia/packages/Luna/An5LJ/src/Grid.jl:78
# ┌ Info: Using PPT ionisation rate.
# └ @ Luna.Interface /Users/larsenk/.julia/packages/Luna/An5LJ/src/Interface.jl:534
# ┌ Info: Found cached PPT rate for 15.760834782784002 eV, 1025.0 nm
# └ @ Luna.Ionisation /Users/larsenk/.julia/packages/Luna/An5LJ/src/Ionisation.jl:144
# ┌ Info: Using mode-averaged propagation.
# ...

# %%
#output4 = prop_capillary(HCF_rad, 0.375, :Ar, 4.0; λ0=1025e-9, energy=1e-3, τfwhm=190e-15, λlims=(650e-9, 1.5e-6), trange=1e-12, modes=4)

# %%
#Plotting.spec_1D(output4, [0.375]; log10=false, λrange=(925e-9, 1125e-9));
#Plotting.time_1D(output3, [1]; trange=(-250e-15, 250e-15),FTL=true);

# %%
Plotting.spec_1D(output1, [1.0]; log10=false, λrange=(925e-9, 1125e-9));
Plotting.spec_1D(output2, [1.0]; log10=false, λrange=(925e-9, 1125e-9));
Plotting.spec_1D(output3, [1.0]; log10=false, λrange=(925e-9, 1125e-9));
Plotting.spec_1D(output4, [1.0]; log10=false, λrange=(925e-9, 1125e-9));
Plotting.spec_1D(output5, [1.0]; log10=false, λrange=(925e-9, 1125e-9));
# Out:
# PyPlot.Figure(PyObject <Figure size 850x500 with 1 Axes>)
# PyPlot.Figure(PyObject <Figure size 850x500 with 1 Axes>)
# PyPlot.Figure(PyObject <Figure size 850x500 with 1 Axes>)
# PyPlot.Figure(PyObject <Figure size 850x500 with 1 Axes>)
# PyPlot.Figure(PyObject <Figure size 850x500 with 1 Axes>)

# %%
Plotting.time_1D(output1, [1]; trange=(-250e-15, 250e-15),FTL=true);
Plotting.time_1D(output2, [1]; trange=(-250e-15, 250e-15),FTL=true);
Plotting.time_1D(output3, [1]; trange=(-250e-15, 250e-15),FTL=true);
Plotting.time_1D(output4, [1]; trange=(-250e-15, 250e-15),FTL=true);
Plotting.time_1D(output5, [1]; trange=(-250e-15, 250e-15),FTL=true);
# Out:
# PyPlot.Figure(PyObject <Figure size 850x500 with 1 Axes>)
# PyPlot.Figure(PyObject <Figure size 850x500 with 1 Axes>)
# PyPlot.Figure(PyObject <Figure size 850x500 with 1 Axes>)
# PyPlot.Figure(PyObject <Figure size 850x500 with 1 Axes>)
# PyPlot.Figure(PyObject <Figure size 850x500 with 1 Axes>)

# %%
Iw_0 = Processing.getIω(output0,:λ,1.0,specrange=(925e-9,1125e-9),resolution=nothing)
Iw_1 = Processing.getIω(output1,:λ,1.0,specrange=(925e-9,1125e-9),resolution=nothing)
Iw_2 = Processing.getIω(output2,:λ,1.0,specrange=(925e-9,1125e-9),resolution=nothing)
Iw_3 = Processing.getIω(output3,:λ,1.0,specrange=(925e-9,1125e-9),resolution=nothing)
Iw_4 = Processing.getIω(output4,:λ,1.0,specrange=(925e-9,1125e-9),resolution=nothing)
Iw_5 = Processing.getIω(output5,:λ,1.0,specrange=(925e-9,1125e-9),resolution=nothing)

It_0 = Processing.getEt(output0,1.0,trange=(-250e-15,250e-15),FTL=true)
It_1 = Processing.getEt(output1,1.0,trange=(-250e-15,250e-15),FTL=true)
It_2 = Processing.getEt(output2,1.0,trange=(-250e-15,250e-15),FTL=true)
It_3 = Processing.getEt(output3,1.0,trange=(-250e-15,250e-15),FTL=true)
It_4 = Processing.getEt(output4,1.0,trange=(-250e-15,250e-15),FTL=true)
It_5 = Processing.getEt(output5,1.0,trange=(-250e-15,250e-15),FTL=true)
# Out:
# ([-2.4933916116061864e-13, -2.4915848060905297e-13, -2.489778000574873e-13, -2.4879711950592167e-13, -2.48616438954356e-13, -2.4843575840279033e-13, -2.482550778512247e-13, -2.4807439729965903e-13, -2.4789371674809336e-13, -2.477130361965277e-13  …  2.4825507785120804e-13, 2.4843575840277367e-13, 2.486164389543394e-13, 2.48797119505905e-13, 2.4897780005747063e-13, 2.4915848060903636e-13, 2.49339161160602e-13, 2.495198417121676e-13, 2.497005222637333e-13, 2.4988120281529894e-13], ComplexF64[2217.2510512478743 + 569.7670460646182im; 1843.3843368241878 + 1012.7471943599011im; … ; 2515.6360708526217 - 1.255723935189386e-7im; 2441.274198573616 + 243.23973918110454im;;], [0.375])

# %%
using CSV, DataFrames

CSV.write("HCF_w0_wavelength.csv", DataFrame(Iw_0[2],:auto), header = false) 
CSV.write("HCF_w0_amp.csv", DataFrame(reshape(Iw_0[1],length(Iw_0[1]),1),:auto), header = false) 
CSV.write("HCF_t0_time.csv", DataFrame(It_0[2],:auto), header = false) 
CSV.write("HCF_t0_amp.csv", DataFrame(reshape(It_0[1],length(It_0[1]),1),:auto), header = false) 

CSV.write("HCF_w1_wavelength.csv", DataFrame(Iw_1[2],:auto), header = false) 
CSV.write("HCF_w1_amp.csv", DataFrame(reshape(Iw_1[1],length(Iw_1[1]),1),:auto), header = false) 
CSV.write("HCF_t1_time.csv", DataFrame(It_1[2],:auto), header = false) 
CSV.write("HCF_t1_amp.csv", DataFrame(reshape(It_1[1],length(It_1[1]),1),:auto), header = false) 

CSV.write("HCF_w2_wavelength.csv", DataFrame(Iw_2[2],:auto), header = false) 
CSV.write("HCF_w2_amp.csv", DataFrame(reshape(Iw_2[1],length(Iw_2[1]),1),:auto), header = false) 
CSV.write("HCF_t2_time.csv", DataFrame(It_2[2],:auto), header = false) 
CSV.write("HCF_t2_amp.csv", DataFrame(reshape(It_2[1],length(It_2[1]),1),:auto), header = false) 

CSV.write("HCF_w3_wavelength.csv", DataFrame(Iw_3[2],:auto), header = false) 
CSV.write("HCF_w3_amp.csv", DataFrame(reshape(Iw_3[1],length(Iw_3[1]),1),:auto), header = false) 
CSV.write("HCF_t3_time.csv", DataFrame(It_3[2],:auto), header = false) 
CSV.write("HCF_t3_amp.csv", DataFrame(reshape(It_3[1],length(It_3[1]),1),:auto), header = false) 

CSV.write("HCF_w4_wavelength.csv", DataFrame(Iw_4[2],:auto), header = false) 
CSV.write("HCF_w4_amp.csv", DataFrame(reshape(Iw_4[1],length(Iw_4[1]),1),:auto), header = false) 
CSV.write("HCF_t4_time.csv", DataFrame(It_4[2],:auto), header = false) 
CSV.write("HCF_t4_amp.csv", DataFrame(reshape(It_4[1],length(It_4[1]),1),:auto), header = false) 

CSV.write("HCF_w5_wavelength.csv", DataFrame(Iw_5[2],:auto), header = false) 
CSV.write("HCF_w5_amp.csv", DataFrame(reshape(Iw_5[1],length(Iw_5[1]),1),:auto), header = false) 
CSV.write("HCF_t5_time.csv", DataFrame(It_5[2],:auto), header = false) 
CSV.write("HCF_t5_amp.csv", DataFrame(reshape(It_5[1],length(It_5[1]),1),:auto), header = false)
# Out:
# "HCF_t5_amp.csv"

# %%
λ0=1025e-9

function prop!(Eω, grid)
    #Fields.prop_mirror!(Eω, grid, :PC70, 10) # 10 chirped mirror bounces
    #Fields.prop_material!(Eω, grid, :Air, 5, λ0) # 5 m of air path total
    #Fields.prop_material!(Eω, grid, :SiO2, 2e-3, λ0) # 2 1-mm windows
    # optimise compression with silica insertion (i.e. wedges)
    #_, Eωopt = Fields.optcomp_material(Eω, grid, :SiO2, λ0, -1e-2, 1e-2)
    _, Eωopt = Fields.optcomp_taylor(Eω, grid, λ0)
    Eω .= Eωopt
end

# non-mutating version of prop! as required for plotting
function prop(grid, Eω)
    Eωout = copy(Eω)
    prop!(Eωout, grid)
    Eωout
end
# Out:
# prop (generic function with 1 method)

# %%
custom0 = Interface.Pulses.LunaPulse(output0;energy=0.8e-3,λ0=1025e-9,propagator=prop!)
custom1 = Interface.Pulses.LunaPulse(output1;energy=0.8e-3,λ0=1025e-9,propagator=prop!)
custom2 = Interface.Pulses.LunaPulse(output2;energy=0.8e-3,λ0=1025e-9,propagator=prop!)
custom3 = Interface.Pulses.LunaPulse(output3;energy=0.8e-3,λ0=1025e-9,propagator=prop!)
custom4 = Interface.Pulses.LunaPulse(output4;energy=0.8e-3,λ0=1025e-9,propagator=prop!)
custom5 = Interface.Pulses.LunaPulse(output5;energy=0.8e-3,λ0=1025e-9,propagator=prop!)
# Out:
# Luna.Interface.Pulses.DataPulse{Luna.Fields.PropagatedField{typeof(prop!), Luna.Fields.DataField}}(:lowest, :linear, Luna.Fields.PropagatedField{typeof(prop!), Luna.Fields.DataField}(prop!, Luna.Fields.DataField([0.0, 4.2450080393078125e12, 8.490016078615625e12, 1.2735024117923438e13, 1.698003215723125e13, 2.1225040196539062e13, 2.5470048235846875e13, 2.9715056275154688e13, 3.39600643144625e13, 3.820507235377031e13  …  4.3086831598974295e15, 4.3129281679367375e15, 4.3171731759760455e15, 4.321418184015353e15, 4.325663192054661e15, 4.329908200093969e15, 4.3341532081332765e15, 4.3383982161725845e15, 4.342643224211892e15, 4.3468882322512e15], [2.6800234005672186e-20, 2.604713448513574e-20, 2.6708085528871368e-20, 5.1142896103159555e-20, 6.802744525662092e-20, 5.096239501634136e-21, 2.4302537869731987e-20, 1.121392718103859e-19, 1.0429099560611593e-20, 1.6255751918424865e-20  …  3.3355231032133654e-20, 5.574535586630698e-20, 7.486977157480062e-20, 7.13658345578521e-20, 4.6111183281026434e
# ...

# %%
HCF_rad_2nd = 200e-6

#output0_2ndstage = prop_capillary(400e-6, 0.25, :Kr, 0; λ0=1025e-9, energy=0.75e-3, λlims=(150e-9, 4e-6), trange=2e-12, pulses = custom0, modes=4)
#output1_2ndstage = prop_capillary(400e-6, 0.25, :Kr, 1; λ0=1025e-9, energy=0.75e-3, λlims=(150e-9, 4e-6), trange=2e-12, pulses = custom1, modes=4)
#output2_2ndstage = prop_capillary(400e-6, 0.25, :Kr, 2; λ0=1025e-9, energy=0.75e-3, λlims=(150e-9, 4e-6), trange=2e-12, pulses = custom2, modes=4)
#output3_2ndstage = prop_capillary(400e-6, 0.25, :Kr, 3; λ0=1025e-9, energy=0.75e-3, λlims=(150e-9, 4e-6), trange=2e-12, pulses = custom3, modes=4)
#output4_2ndstage = prop_capillary(400e-6, 0.25, :Kr, 4; λ0=1025e-9, energy=0.75e-3, λlims=(150e-9, 4e-6), trange=2e-12, pulses = custom4, modes=4)
#output5_2ndstage = prop_capillary(400e-6, 0.25, :Kr, 5; λ0=1025e-9, energy=0.75e-3, λlims=(150e-9, 4e-6), trange=2e-12, pulses = custom5, modes=4)

#output0_2ndstage = prop_capillary(536e-6, 1.0, :Ar, 0; λ0=1025e-9, energy=0.8e-3, λlims=(150e-9, 4e-6), trange=2e-12, pulses = custom0)
#output1_2ndstage = prop_capillary(536e-6, 1.0, :Ar, 1; λ0=1025e-9, energy=0.8e-3, λlims=(150e-9, 4e-6), trange=2e-12, pulses = custom1)
#output2_2ndstage = prop_capillary(536e-6, 1.0, :Ar, 2; λ0=1025e-9, energy=0.8e-3, λlims=(150e-9, 4e-6), trange=2e-12, pulses = custom2)
#output3_2ndstage = prop_capillary(536e-6, 1.0, :Ar, 3; λ0=1025e-9, energy=0.8e-3, λlims=(150e-9, 4e-6), trange=2e-12, pulses = custom3)
#output4_2ndstage = prop_capillary(536e-6, 1.0, :Ar, 4; λ0=1025e-9, energy=0.8e-3, λlims=(150e-9, 4e-6), trange=2e-12, pulses = custom4)
#output5_2ndstage = prop_capillary(536e-6, 1.0, :Ar, 5; λ0=1025e-9, energy=0.8e-3, λlims=(150e-9, 4e-6), trange=2e-12, pulses = custom5)

output0_2ndstage = prop_capillary(HCF_rad_2nd, 0.375, :Ar, 0.0; λ0=1025e-9, energy=0.8e-3, λlims=(300e-9, 2.5e-6), trange=1e-12, pulses = custom4)
output1_2ndstage = prop_capillary(HCF_rad_2nd, 0.375, :Ar, 1.0; λ0=1025e-9, energy=0.8e-3, λlims=(300e-9, 2.5e-6), trange=1e-12, pulses = custom4)
output2_2ndstage = prop_capillary(HCF_rad_2nd, 0.375, :Ar, 2.0; λ0=1025e-9, energy=0.8e-3, λlims=(300e-9, 2.5e-6), trange=1e-12, pulses = custom4)
output3_2ndstage = prop_capillary(HCF_rad_2nd, 0.375, :Ar, 3.0; λ0=1025e-9, energy=0.8e-3, λlims=(300e-9, 2.5e-6), trange=1e-12, pulses = custom4)
output4_2ndstage = prop_capillary(HCF_rad_2nd, 0.375, :Ar, 4.0; λ0=1025e-9, energy=0.8e-3, λlims=(300e-9, 2.5e-6), trange=1e-12, pulses = custom4)
output5_2ndstage = prop_capillary(HCF_rad_2nd, 0.375, :Ar, 5.0; λ0=1025e-9, energy=0.8e-3, λlims=(300e-9, 2.5e-6), trange=1e-12, pulses = custom4)
# Out:
# ┌ Info: X+Y polarisation not required.
# └ @ Luna.Interface /Users/larsenk/.julia/packages/Luna/An5LJ/src/Interface.jl:353
# ┌ Info: Freq limits 0.12 - 1.00 PHz
# └ @ Luna.Grid /Users/larsenk/.julia/packages/Luna/An5LJ/src/Grid.jl:40
# ┌ Info: Samples needed: 5995.85, samples: 8192, δt = 166.78 as
# └ @ Luna.Grid /Users/larsenk/.julia/packages/Luna/An5LJ/src/Grid.jl:44
# ┌ Info: Requested time window: 1000.0 fs, actual time window: 1366.3 fs
# └ @ Luna.Grid /Users/larsenk/.julia/packages/Luna/An5LJ/src/Grid.jl:46
# ┌ Info: Grid: samples 4096 / 8192, ωmax 9.42e+15 / 1.88e+16
# └ @ Luna.Grid /Users/larsenk/.julia/packages/Luna/An5LJ/src/Grid.jl:78
# ┌ Info: Using PPT ionisation rate.
# └ @ Luna.Interface /Users/larsenk/.julia/packages/Luna/An5LJ/src/Interface.jl:534
# ┌ Info: Found cached PPT rate for 15.760834782784002 eV, 1025.0 nm
# └ @ Luna.Ionisation /Users/larsenk/.julia/packages/Luna/An5LJ/src/Ionisation.jl:144
# ┌ Info: Using mode-averaged propagation.
# ...

# %%
HCF_rad_2nd = 200e-6
playtime = prop_capillary(HCF_rad_2nd, 0.375, :Ar, 1.0; λ0=1025e-9, energy=0.8e-3, λlims=(400e-9, 2.5e-6), trange=1e-12, pulses = custom4, modes=4)
# Out:
# ┌ Info: X+Y polarisation not required.
# └ @ Luna.Interface /Users/larsenk/.julia/packages/Luna/An5LJ/src/Interface.jl:353
# ┌ Info: Freq limits 0.12 - 0.75 PHz
# └ @ Luna.Grid /Users/larsenk/.julia/packages/Luna/An5LJ/src/Grid.jl:40
# ┌ Info: Samples needed: 4496.89, samples: 8192, δt = 222.38 as
# └ @ Luna.Grid /Users/larsenk/.julia/packages/Luna/An5LJ/src/Grid.jl:44
# ┌ Info: Requested time window: 1000.0 fs, actual time window: 1821.7 fs
# └ @ Luna.Grid /Users/larsenk/.julia/packages/Luna/An5LJ/src/Grid.jl:46
# ┌ Info: Grid: samples 4096 / 8192, ωmax 7.06e+15 / 1.41e+16
# └ @ Luna.Grid /Users/larsenk/.julia/packages/Luna/An5LJ/src/Grid.jl:78
# ┌ Info: Using PPT ionisation rate.
# └ @ Luna.Interface /Users/larsenk/.julia/packages/Luna/An5LJ/src/Interface.jl:534
# ┌ Info: Found cached PPT rate for 15.760834782784002 eV, 1025.0 nm
# └ @ Luna.Ionisation /Users/larsenk/.julia/packages/Luna/An5LJ/src/Ionisation.jl:144
# ┌ Info: Using radial modal integral.
# ...

# %%
#Plotting.prop_2D(output4_2ndstage,trange=(-500e-15, 500e-15));

# %%
#monitor higher order modes and find conditions where they are not significantly contribution (keep it below a few percent)
#gotta stay at lower pressures!!!

#Plotting.time_1D(playtime, [1.0]; trange=(-250e-15, 250e-15),FTL=true);
#Plotting.spec_1D(playtime, [0.375]; log10=false, λrange=(750e-9, 1300e-9));

Plotting.time_1D(output1_2ndstage, [0.375]; trange=(-250e-15, 250e-15),FTL=true);
Plotting.time_1D(output2_2ndstage, [0.375]; trange=(-250e-15, 250e-15),FTL=true);
Plotting.time_1D(output3_2ndstage, [0.375]; trange=(-250e-15, 250e-15),FTL=true);
Plotting.time_1D(output4_2ndstage, [0.375]; trange=(-250e-15, 250e-15),FTL=true);
Plotting.time_1D(output5_2ndstage, [0.375]; trange=(-250e-15, 250e-15),FTL=true);
# Out:
# PyPlot.Figure(PyObject <Figure size 850x500 with 1 Axes>)
# PyPlot.Figure(PyObject <Figure size 850x500 with 1 Axes>)
# PyPlot.Figure(PyObject <Figure size 850x500 with 1 Axes>)
# PyPlot.Figure(PyObject <Figure size 850x500 with 1 Axes>)
# PyPlot.Figure(PyObject <Figure size 850x500 with 1 Axes>)

# %%
Plotting.spec_1D(output1_2ndstage, [1.0]; log10=false, λrange=(400e-9, 1650e-9));
Plotting.spec_1D(output2_2ndstage, [1.0]; log10=false, λrange=(400e-9, 1650e-9));
Plotting.spec_1D(output3_2ndstage, [1.0]; log10=false, λrange=(400e-9, 1650e-9));
Plotting.spec_1D(output4_2ndstage, [1.0]; log10=false, λrange=(400e-9, 1650e-9));
Plotting.spec_1D(output5_2ndstage, [1.0]; log10=false, λrange=(400e-9, 1650e-9));
# Out:
# PyPlot.Figure(PyObject <Figure size 850x500 with 1 Axes>)
# PyPlot.Figure(PyObject <Figure size 850x500 with 1 Axes>)
# PyPlot.Figure(PyObject <Figure size 850x500 with 1 Axes>)
# PyPlot.Figure(PyObject <Figure size 850x500 with 1 Axes>)
# PyPlot.Figure(PyObject <Figure size 850x500 with 1 Axes>)

# %%
Iw_0_2nd = Processing.getIω(output0_2ndstage,:λ,0.75,specrange=(700e-9,1350e-9),resolution=nothing)
Iw_1_2nd = Processing.getIω(output1_2ndstage,:λ,0.75,specrange=(700e-9,1350e-9),resolution=nothing)
Iw_2_2nd = Processing.getIω(output2_2ndstage,:λ,0.75,specrange=(700e-9,1350e-9),resolution=nothing)
Iw_3_2nd = Processing.getIω(output3_2ndstage,:λ,0.75,specrange=(700e-9,1350e-9),resolution=nothing)
Iw_4_2nd = Processing.getIω(output4_2ndstage,:λ,0.75,specrange=(700e-9,1350e-9),resolution=nothing)
Iw_5_2nd = Processing.getIω(output5_2ndstage,:λ,0.75,specrange=(700e-9,1350e-9),resolution=nothing)

It_0_2nd = Processing.getEt(output0_2ndstage,0.75,trange=(-250e-15,250e-15),FTL=true)
It_1_2nd = Processing.getEt(output1_2ndstage,0.75,trange=(-250e-15,250e-15),FTL=true)
It_2_2nd = Processing.getEt(output2_2ndstage,0.75,trange=(-250e-15,250e-15),FTL=true)
It_3_2nd = Processing.getEt(output3_2ndstage,0.75,trange=(-250e-15,250e-15),FTL=true)
It_4_2nd = Processing.getEt(output4_2ndstage,0.75,trange=(-250e-15,250e-15),FTL=true)
It_5_2nd = Processing.getEt(output5_2ndstage,0.75,trange=(-250e-15,250e-15),FTL=true)
# Out:
# ([-2.4983950730341586e-13, -2.4975611627961634e-13, -2.496727252558168e-13, -2.495893342320173e-13, -2.4950594320821775e-13, -2.494225521844182e-13, -2.493391611606187e-13, -2.4925577013681916e-13, -2.4917237911301963e-13, -2.490889880892201e-13  …  2.493391611605671e-13, 2.4942255218436657e-13, 2.4950594320816615e-13, 2.4958933423196573e-13, 2.496727252557652e-13, 2.497561162795647e-13, 2.4983950730336427e-13, 2.4992289832716385e-13, 2.5000628935096333e-13, 2.500896803747628e-13], ComplexF64[-2802.650162794178 + 3598.8758292630996im; -3103.684375629256 + 4060.3517426067265im; … ; -2485.3949123923185 - 5.249605651415531e-7im; -2571.799642838662 + 2115.7532081095087im;;], [0.375])

# %%
#using CSV, DataFrames

CSV.write("HCF_w0_wavelength_2nd.csv", DataFrame(Iw_0_2nd[2],:auto), header = false) 
CSV.write("HCF_w0_amp_2nd.csv", DataFrame(reshape(Iw_0_2nd[1],length(Iw_0_2nd[1]),1),:auto), header = false) 
CSV.write("HCF_t0_time_2nd.csv", DataFrame(It_0_2nd[2],:auto), header = false) 
CSV.write("HCF_t0_amp_2nd.csv", DataFrame(reshape(It_0_2nd[1],length(It_0_2nd[1]),1),:auto), header = false) 

CSV.write("HCF_w1_wavelength_2nd.csv", DataFrame(Iw_1_2nd[2],:auto), header = false) 
CSV.write("HCF_w1_amp_2nd.csv", DataFrame(reshape(Iw_1_2nd[1],length(Iw_1_2nd[1]),1),:auto), header = false) 
CSV.write("HCF_t1_time_2nd.csv", DataFrame(It_1_2nd[2],:auto), header = false) 
CSV.write("HCF_t1_amp_2nd.csv", DataFrame(reshape(It_1_2nd[1],length(It_1_2nd[1]),1),:auto), header = false) 

CSV.write("HCF_w2_wavelength_2nd.csv", DataFrame(Iw_2_2nd[2],:auto), header = false) 
CSV.write("HCF_w2_amp_2nd.csv", DataFrame(reshape(Iw_2_2nd[1],length(Iw_2_2nd[1]),1),:auto), header = false) 
CSV.write("HCF_t2_time_2nd.csv", DataFrame(It_2_2nd[2],:auto), header = false) 
CSV.write("HCF_t2_amp_2nd.csv", DataFrame(reshape(It_2_2nd[1],length(It_2_2nd[1]),1),:auto), header = false) 

CSV.write("HCF_w3_wavelength_2nd.csv", DataFrame(Iw_3_2nd[2],:auto), header = false) 
CSV.write("HCF_w3_amp_2nd.csv", DataFrame(reshape(Iw_3_2nd[1],length(Iw_3_2nd[1]),1),:auto), header = false) 
CSV.write("HCF_t3_time_2nd.csv", DataFrame(It_3_2nd[2],:auto), header = false) 
CSV.write("HCF_t3_amp_2nd.csv", DataFrame(reshape(It_3_2nd[1],length(It_3_2nd[1]),1),:auto), header = false) 

CSV.write("HCF_w4_wavelength_2nd.csv", DataFrame(Iw_4_2nd[2],:auto), header = false) 
CSV.write("HCF_w4_amp_2nd.csv", DataFrame(reshape(Iw_4_2nd[1],length(Iw_4_2nd[1]),1),:auto), header = false) 
CSV.write("HCF_t4_time_2nd.csv", DataFrame(It_4_2nd[2],:auto), header = false) 
CSV.write("HCF_t4_amp_2nd.csv", DataFrame(reshape(It_4_2nd[1],length(It_4_2nd[1]),1),:auto), header = false) 

CSV.write("HCF_w5_wavelength_2nd.csv", DataFrame(Iw_5_2nd[2],:auto), header = false) 
CSV.write("HCF_w5_amp_2nd.csv", DataFrame(reshape(Iw_5_2nd[1],length(Iw_5_2nd[1]),1),:auto), header = false) 
CSV.write("HCF_t5_time_2nd.csv", DataFrame(It_5_2nd[2],:auto), header = false) 
CSV.write("HCF_t5_amp_2nd.csv", DataFrame(reshape(It_5_2nd[1],length(It_5_2nd[1]),1),:auto), header = false)
# Out:
# "HCF_t5_amp_2nd.csv"

# %%
#custom0_soliton = Interface.Pulses.LunaPulse(output0_2ndstage;energy=0.5e-3,λ0=1025e-9,propagator=prop!)
#custom1_soliton = Interface.Pulses.LunaPulse(output1_2ndstage;energy=0.5e-3,λ0=1025e-9,propagator=prop!)
#custom2_soliton = Interface.Pulses.LunaPulse(output2_2ndstage;energy=0.5e-3,λ0=1025e-9,propagator=prop!)
#custom3_soliton = Interface.Pulses.LunaPulse(output3_2ndstage;energy=0.5e-3,λ0=1025e-9,propagator=prop!)
#custom4_soliton = Interface.Pulses.LunaPulse(output4_2ndstage;energy=0.5e-3,λ0=1025e-9,propagator=prop!)
#custom5_soliton = Interface.Pulses.LunaPulse(output5_2ndstage;energy=0.5e-3,λ0=1025e-9,propagator=prop!)

custom1_soliton = Interface.Pulses.LunaPulse(output1_2ndstage;energy=0.64e-3,λ0=1025e-9,propagator=prop!)
custom2_soliton = Interface.Pulses.LunaPulse(output2_2ndstage;energy=0.64e-3,λ0=1025e-9,propagator=prop!)
custom3_soliton = Interface.Pulses.LunaPulse(output3_2ndstage;energy=0.64e-3,λ0=1025e-9,propagator=prop!)
custom4_soliton = Interface.Pulses.LunaPulse(output4_2ndstage;energy=0.64e-3,λ0=1025e-9,propagator=prop!)
custom5_soliton = Interface.Pulses.LunaPulse(output5_2ndstage;energy=0.64e-3,λ0=1025e-9,propagator=prop!)
# Out:
# Luna.Interface.Pulses.DataPulse{Luna.Fields.PropagatedField{typeof(prop!), Luna.Fields.DataField}}(:lowest, :linear, Luna.Fields.PropagatedField{typeof(prop!), Luna.Fields.DataField}(prop!, Luna.Fields.DataField([0.0, 4.59875870925013e12, 9.19751741850026e12, 1.379627612775039e13, 1.839503483700052e13, 2.299379354625065e13, 2.759255225550078e13, 3.219131096475091e13, 3.679006967400104e13, 4.138882838325117e13  …  9.376869008161014e15, 9.381467766870264e15, 9.386066525579516e15, 9.390665284288766e15, 9.395264042998016e15, 9.399862801707266e15, 9.404461560416516e15, 9.409060319125766e15, 9.413659077835016e15, 9.418257836544266e15], [1.1171459314165306e-16, 5.69560342398788e-17, 2.5159752717037095e-18, 5.669913979791741e-17, 1.2001658895083918e-16, 7.988629305531626e-17, 3.3680680790109894e-18, 5.444474346832143e-17, 1.5834475204195542e-16, 1.085576250643326e-16  …  3.611080350765146e-20, 2.9384096488300763e-20, 1.0673964307876678e-19, 9.219157516408031e-20, 5.2593357586860634e-20, 1.25
# ...

# %%
#output0_HCF = prop_capillary(150e-6, 2.0, :Ne, 0; λ0=1025e-9, energy=0.5e-3, λlims=(150e-9, 4e-6), trange=2e-12, pulses = custom0_soliton)
#output1_HCF = prop_capillary(150e-6, 2.0, :Ne, 0.4; λ0=1025e-9, energy=0.5e-3, λlims=(150e-9, 4e-6), trange=2e-12, pulses = custom1_soliton)
#output2_HCF = prop_capillary(100e-6, 1.0, :Ar, 0.1; λ0=1025e-9, energy=0.5e-3, λlims=(150e-9, 4e-6), trange=2e-12, pulses = custom2_soliton)
#output3_HCF = prop_capillary(150e-6, 2.0, :Ne, 0.6; λ0=1025e-9, energy=0.5e-3, λlims=(150e-9, 4e-6), trange=2e-12, pulses = custom3_soliton)
#output4_HCF = prop_capillary(100e-6, 1.0, :He, 1.0; λ0=1025e-9, energy=0.5e-3, λlims=(100e-9, 4e-6), trange=2e-12, pulses = custom4_soliton)
#output5_HCF = prop_capillary(150e-6, 2.0, :Ne, 2; λ0=1025e-9, energy=0.5e-3, λlims=(150e-9, 4e-6), trange=2e-12, pulses = custom5_soliton)

output4_HCF = prop_capillary(100e-6, 1.0, :He, 1.5; λ0=1025e-9, energy=0.64e-3, λlims=(100e-9, 4e-6), trange=1e-12, pulses = custom1_soliton)
# Out:
# ┌ Info: X+Y polarisation not required.
# └ @ Luna.Interface /Users/larsenk/.julia/packages/Luna/An5LJ/src/Interface.jl:353
# ┌ Info: Freq limits 0.07 - 3.00 PHz
# └ @ Luna.Grid /Users/larsenk/.julia/packages/Luna/An5LJ/src/Grid.jl:40
# ┌ Info: Samples needed: 17987.55, samples: 32768, δt = 55.59 as
# └ @ Luna.Grid /Users/larsenk/.julia/packages/Luna/An5LJ/src/Grid.jl:44
# ┌ Info: Requested time window: 1000.0 fs, actual time window: 1821.7 fs
# └ @ Luna.Grid /Users/larsenk/.julia/packages/Luna/An5LJ/src/Grid.jl:46
# ┌ Info: Grid: samples 16384 / 32768, ωmax 2.83e+16 / 5.65e+16
# └ @ Luna.Grid /Users/larsenk/.julia/packages/Luna/An5LJ/src/Grid.jl:78
# ┌ Info: Using PPT ionisation rate.
# └ @ Luna.Interface /Users/larsenk/.julia/packages/Luna/An5LJ/src/Interface.jl:534
# ┌ Info: Found cached PPT rate for 24.588208407672 eV, 1025.0 nm
# └ @ Luna.Ionisation /Users/larsenk/.julia/packages/Luna/An5LJ/src/Ionisation.jl:144
# ┌ Info: Using mode-averaged propagation.
# ...

# %%
Plotting.prop_2D(output4_HCF,:λ,trange=(-20e-15, 50e-15),λrange=(100e-9, 1600e-9));
# Out:
# PyPlot.Figure(PyObject <Figure size 1200x400 with 4 Axes>)

# %%
Plotting.spectrogram(output4_HCF, 0.59; trange=(-10e-15, 25e-15), λrange=(100e-9, 1200e-9),N=512,fw=1e-15);
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 2 Axes>)

# %%
Plotting.time_1D(output4_HCF, [0.59]; trange=(0e-15, 25e-15));
# Out:
# PyPlot.Figure(PyObject <Figure size 850x500 with 1 Axes>)

# %%
Plotting.spec_1D(output4_HCF, [0.62]; log10=false, λrange=(100e-9, 1600e-9));
Plotting.spec_1D(output4_HCF, [0.62]; log10=false, λrange=(100e-9, 200e-9));
# Out:
# PyPlot.Figure(PyObject <Figure size 850x500 with 1 Axes>)
# PyPlot.Figure(PyObject <Figure size 850x500 with 1 Axes>)

# %%
Plotting.time_1D(output4_HCF, [0.59]; trange=(5e-15, 20e-15),bandpass=(100e-9, 200e-9));
# Out:
# PyPlot.Figure(PyObject <Figure size 850x500 with 1 Axes>)

# %%
Plotting.prop_2D(output2_HCF,:λ,trange=(-20e-15, 50e-15),λrange=(150e-9, 2500e-9));

# %%
#Plotting.time_1D(output3_HCF, [0.75]; trange=(0e-15, 25e-15));
#Plotting.time_1D(output2_HCF, [1.35]; trange=(0e-15, 25e-15));
Plotting.time_1D(output2_HCF, [1.0]; trange=(0e-15, 25e-15));

# %%
#Plotting.spec_1D(output3_HCF, [0.75]; log10=false, λrange=(150e-9, 1600e-9));
#Plotting.spec_1D(output3_HCF, [1.35]; log10=false, λrange=(150e-9, 1600e-9));
Plotting.spec_1D(output3_HCF, [1.0]; log10=false, λrange=(150e-9, 1600e-9));

# %%
#Plotting.time_1D(output3_HCF, [1.35]; trange=(5e-15, 40e-15),bandpass=(150e-9, 250e-9));
Plotting.time_1D(output3_HCF, [1.0]; trange=(5e-15, 40e-15),bandpass=(150e-9, 250e-9));
