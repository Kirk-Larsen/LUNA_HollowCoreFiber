# %%
#= 
first section (first 428 lines) has all the functions (external to Luna) and variables/parameters used
second section is where the 1st is propagated
third section is where the 2nd is propagated 
fourth section is where the 3rd is propagated and an RDW is hopefully emitted
fifth section is where you can set a range and analysis the 3rd stage
sixth section is where the pickoff mirrors HD7203 or HD7201 is simulated (need the csv in the file location to use) and compression of the RDW 
seventh section is where you can grab any stage of the simulation and overlay it with an experimental spectrum saved in the file location 
eighth and ninth section produces graphs similar to Luna graphs but with more user freedom


The first stage (stg1) fiber to broaden bandwidth then compress 330 fs pulse to ~61 fs with a series of optical components including chirp mirrors
The second stage (stg2) fiber broadens bandwidth even more then compresses the pulse further down to ~9fs
Lastly, the third stage (stg3) is the soliton stage which is where the UV RWD emission is generated via adjusting the pressure of the gas and the input energy of the pulse (to limit ionization)
=#

# %%
#= Array simulation:
  Check stage 1 parameters are correct:
        gas1 = :Ar		#gas in the fiber, Ar is Argon
        energy1 = 2000e-6	#pulse energy in Joules
        pressure1 = 2.0		#gas pressure in bar
  Check stage 2 paramters, the ones listed below will give an output pulse duration of 8.89fs after compression
    gas2=  :Ar #gas in the fiber, Ar is argon
    energy2= 1860e-6 #in joules
    pressure2= 0.5 #in bar
  Manually set stage 3 gas, pressure, energy parameters in fourth cell
=#

# %%
using Luna  #declare package to use propagation functions, need to add to Julia REPL before first use, see GitHub for documentation
import PyPlot as plt #for some plotting
using Plots #for some other plotting
gr() #backend for Plots
using DelimitedFiles #for reading in csv files, used in  propHD7203 and hd7201
using PyCall #this line and next are how to import numpy into Julia
np = pyimport("numpy")
using LinearAlgebra #for central wavelength calculation

##global variables:
    #parameters of input pulse using the Carbide laser
    λ0 = 1030e-9	    #central wavelength in meters
    τfwhm_initial= 330e-15	#pulse duration in seconds
    #parameters of the first fiber
    a1 = 268e-6		#core radius in meters
    flength1 = 1.0 	#fiber length in meters
    gas1=:Ar #type of gas, Ar is Argon
    energy1=2000e-6 #in joules
    pressure1=2.0 #in bar
    #parameters of the second fiber
    gas2=:Ar
    energy2= 1860e-6 #in joules
    pressure2= .5 #in bar
    a2 = 268e-6		#core radius in meters
    flength2 = 1.5 	#fiber length in meters
    #parameters of the third fiber
    a3 = 100e-6		#core radius in meters
    flength3 = 1.0	#fiber length in meters
    #for stg1, stg2, stg3 functions to make arrays which are mutuable in and out of functions
    compressor_stg1 =  Array{Any}(undef,1) #only using the first index but need array since mutuable in/out of functions
    compressor_stg2 =  Array{Any}(undef,6) #one index for each tested output pulse duration
    compressor_stg3 =  Array{Any}(undef,5,100) #arbituary chosen size; first index corresponds to stg2[a] for LunaPulse, second is the properties incoming to 3rd stage
    box =  Array{Any}(undef,1) #for propagation of pickoff mirrors in soliton box
    #plotting/grid parameters
    FTL=false #turns off the transformed limited case for various time domain graphs
    modes= 4 		 #total number of modes
    trange1 = 1e-12 	    #time grid size in seconds for 1st stage
    λrange1=(700e-9, 1200e-9) #grid wavelength range in meters for plots for graphs
    λlims_stg1 = (700e-9, 1200e-9) #grid wavelength range in meters for fibers for propagation
    trange2 = 500e-15  	    #time grid size in seconds 
    λrange2=(700e-9, 1200e-9) #grid wavelength range in meters for graphs
    λlims_stg2 = (200e-9, 3e-6) #grid wavelength range in meters for fibers for propagation
    trange3 = 300e-15	    #time grid size in seconds
    λrange3= (100e-9, 1400e-9) #grid wavelength range in meters for graphs
    λlims_stg3 = (100e-9, 1400e-9) #grid wavelength range in meters for fibers for propagation

    a=1 #arbituary indexes to save compressor func as arrays 
    i=1


##functions:

#return central wavelength for given length in fiber for given wavelegnth range
function get_central_wavelength(i,specrange, flength, func)
    λ, Iλ=Processing.getIω(func,:λ, flength; specrange) #get arrays from output SED for wavelengths in specrange at flength
    Iλd=Iλ[:,1,1] #only 1st mode
    P=LinearAlgebra.dot(λ[:], Iλd[:]) #calculate central wavelength: (1/TotalPower)*sum(λ*SED)
    λ00[i]=P/sum(Iλd)
end

#:::'##::::'######::'########:::::'######::'########::::'###:::::'######:::'########:
#:'####:::'##... ##:... ##..:::::'##... ##:... ##..::::'## ##:::'##... ##:: ##.....::
#:.. ##::: ##:::..::::: ##::::::: ##:::..::::: ##:::::'##:. ##:: ##:::..::: ##:::::::
#::: ##:::. ######::::: ##:::::::. ######::::: ##::::'##:::. ##: ##::'####: ######:::
#::: ##::::..... ##:::: ##::::::::..... ##:::: ##:::: #########: ##::: ##:: ##...::::
#::: ##:::'##::: ##:::: ##:::::::'##::: ##:::: ##:::: ##.... ##: ##::: ##:: ##:::::::
#:'######:. ######::::: ##:::::::. ######::::: ##:::: ##:::: ##:. ######::: ########:
#:......:::......::::::..:::::::::......::::::..:::::..:::::..:::......::::........::

#simulates the pulse down the first fiber
function stg1(gas, energy, pressure)
    #propagate through the first stage fiber to broaden bandwidth with the parameters listed above
    compressor_stg1[1]= prop_capillary(a1, flength1, gas, pressure; λ0=λ0, τfwhm=τfwhm_initial, energy, λlims=λlims_stg1, trange=trange1, modes) 
end
        
#compress in time the first stage with chirp mirrors
# this mutates its input as required for the LunaPulse
function prop1!(Eω, grid)
    Fields.prop_material!(Eω, grid, :SiO2, 1e-3, λ0) # 1 1-mm window
   Fields.prop_material!(Eω, grid, :BK7, 2.1e-3, λ0) # 1 bk7 lens LA1254-Bc thorlabs
    Fields.prop_material!(Eω, grid, :Air, 2, λ0) # 2m of air
    Fields.prop_mirror!(Eω, grid, :HD59, 8) #chirp mirror bounces
   Fields.prop_material!(Eω, grid, :Air, 2, λ0) # 2m of air path total
    Fields.prop_material!(Eω, grid, :BK7, 2.1e-3, λ0) # 1 bk7 lenses LA1254-Bc thorlabs
    Fields.prop_material!(Eω, grid, :SiO2, 1e-3, λ0) # 1 1-mm window
    _, Eωopt = Fields.optcomp_material(Eω, grid, :SiO2, λ0, -1e-3, 1e-3) # optimizing compression, last numbers are  min_thickness then max_thickness
    Eω .= Eωopt
end
    
# non-mutating version of prop! as required for plotting
function prop1(grid, Eω)
    Eωout = copy(Eω)
    prop1!(Eωout, grid)
    Eωout
end


#:'#######::'##::: ##:'########::::::'######::'########::::'###:::::'######:::'########:
#'##.... ##: ###:: ##: ##.... ##::::'##... ##:... ##..::::'## ##:::'##... ##:: ##.....::
#..::::: ##: ####: ##: ##:::: ##:::: ##:::..::::: ##:::::'##:. ##:: ##:::..::: ##:::::::
#:'#######:: ## ## ##: ##:::: ##::::. ######::::: ##::::'##:::. ##: ##::'####: ######:::
#'##:::::::: ##. ####: ##:::: ##:::::..... ##:::: ##:::: #########: ##::: ##:: ##...::::
# ##:::::::: ##:. ###: ##:::: ##::::'##::: ##:::: ##:::: ##.... ##: ##::: ##:: ##:::::::
# #########: ##::. ##: ########:::::. ######::::: ##:::: ##:::: ##:. ######::: ########:
#.........::..::::..::........:::::::......::::::..:::::..:::::..:::......::::........::

#simulates the pulse down the second fiber
function stg2(a, gas, energy, pressure) 
    #obtain pulse from the first fiber end via LunaPulse
     pulse_in_stg2 = Pulses.LunaPulse(compressor_stg1[1]; energy, propagator=prop1!) #input pulse from the 1st stage
    #propagate through the second stage fiber to broaden bandwidth even more, with parameters listed above
    compressor_stg2[a]= prop_capillary(a2, flength2, gas, pressure; pulses=[pulse_in_stg2], λ0=λ0, trange=trange2, λlims=λlims_stg2, modes=modes)
end

#compress in time the second stage with chirp mirrors and other optical components
#=physical order in lab: First fiber>optical components>second fiber> 1mm fused silica window >4-5 m of air path length >1mm MgF2 window> 4 (2 pairs) of PC147 chirped mirrors from ultrafast innovations 6 (3 pairs) of PC147 chirped mirrors from ultrafast innovations  > 3.5mm fused silica polarizer > wedges >third fiber     =#
#this mutates its input as required for the LunaPulse
function prop2!(Eω, grid)
    Fields.prop_material!(Eω, grid, :SiO2, 1e-3, λ0) # 1 1-mm fused silica window 
    Fields.prop_material!(Eω, grid, :Air, 3, λ0) # 4m of air total
    Fields.prop_material!(Eω, grid, :MgF2, 1e-3, λ0) #1mm Magnesium Fluoride window
    Fields.prop_mirror!(Eω, grid, :PC147, 4) #chirped mirror bounces (not pairs but need to be in multiples of 2 due to the material induced out of phase oscillations of GDD)
    Fields.prop_material!(Eω, grid, :SiO2, 3.5e-3, λ0) # 1 3.5 mm fused silica polarizer
  _, Eωopt = Fields.optcomp_material(Eω, grid, :SiO2, λ0, -2e-3, 2e-3) #wedges for optimizing compression, last numbers are  min_thickness then max_thickness
  Eω .= Eωopt
end

# non-mutating version of prop! as required for plotting
function prop2(grid, Eω)
    Eωout = copy(Eω)
    prop2!(Eωout, grid)
    Eωout
end



#:'#######::'########::'########::::::'######::'########::::'###:::::'######:::'########:
#'##.... ##: ##.... ##: ##.... ##::::'##... ##:... ##..::::'## ##:::'##... ##:: ##.....::
#..::::: ##: ##:::: ##: ##:::: ##:::: ##:::..::::: ##:::::'##:. ##:: ##:::..::: ##:::::::
#:'#######:: ########:: ##:::: ##::::. ######::::: ##::::'##:::. ##: ##::'####: ######:::
#:...... ##: ##.. ##::: ##:::: ##:::::..... ##:::: ##:::: #########: ##::: ##:: ##...::::
#'##:::: ##: ##::. ##:: ##:::: ##::::'##::: ##:::: ##:::: ##.... ##: ##::: ##:: ##:::::::
#. #######:: ##:::. ##: ########:::::. ######::::: ##:::: ##:::: ##:. ######::: ########:
#:.......:::..:::::..::........:::::::......::::::..:::::..:::::..:::......::::........::

#simulates the pulse down the third fiber
function stg3(a, i, gas3, energy3, pressure3, infunc) 
    #obtain pulse from the first fiber end via LunaPulse
    pulse_in_stg3 = Pulses.LunaPulse(infunc; energy=energy3, propagator=prop2!) #input pulse from the 2nd stage
    #propagate through the second stage fiber to broaden bandwidth even more, with parameters listed above
    compressor_stg3[a,i]= prop_capillary(a3, flength3, gas3, pressure3; pulses=[pulse_in_stg3], λ0=λ0, trange=trange3, λlims=λlims_stg3, modes=modes)
end


#'####:'##::: ##::::'########:::'#######::'##::::'##:
#. ##:: ###:: ##:::: ##.... ##:'##.... ##:. ##::'##::
#: ##:: ####: ##:::: ##:::: ##: ##:::: ##::. ##'##:::
#: ##:: ## ## ##:::: ########:: ##:::: ##:::. ###::::
#: ##:: ##. ####:::: ##.... ##: ##:::: ##::: ## ##:::
#: ##:: ##:. ###:::: ##:::: ##: ##:::: ##:: ##:. ##::
#'####: ##::. ##:::: ########::. #######:: ##:::. ##:
#....::..::::..:::::........::::.......:::..:::::..::

#calculates angular frequency 
function wlfreq(ωλ) 
    c=3e8 #speed of light in vacuum 
    2π*c/ωλ
end

#pickoff mirror for 450 to 550nm from UFI, need to have the data file stored on computer where the varaible dat speficies with format: col1 - wavelength, col2 - GDD correspondong to col1, col3- wavelength, col4- reflecivity corresponding to col3
function propHD7201!(Eω, grid) #mutuable function for LunaPulse
    dat = readdlm(joinpath(Utils.datadir(), "\\Users\\kinca\\Documents\\ucf\\research\\lcls\\code\\61923\\mirrors\\HD7201.csv"), ','; skipstart=1)  #read data from file
    λR = dat[:, 1] * 1e-9 #assign 1st colou
    R = dat[:, 2] # reflectivity per mirror 
    λGDD = dat[:, 3] * 1e-9
    ω =  wlfreq.(λGDD)
    GDD = dat[:, 4] .* 1e-30 # GDD per mirror
    reflections=1
    λ0=1030e-9
    λmin=450e-9
    λmax=550e-9
    Fields.prop_material!(Eω, grid, :MgF2, 1e-3, λ0) # 1 1-mm  window 
    _, Eωopt = Fields.optcomp_material(Eω, grid, :Air, λ0, -2, 2) #optimizing compression, last numbers are  min_thickness then max_thickness
    Eω .= Eωopt
    Fields.prop_mirror!(Eω, grid, reflections, λR, R, λGDD, GDD, λ0, λmin, λmax)
end
function propHD7201(grid, Eω) #nonmutuable function for graphs
    Eωout = copy(Eω)
    propHD7201!(Eωout, grid)
    Eωout
end

#pickoff mirror for  350 to 460nm from UFI, need to have the data file stored on computer where the varaible dat speficies with format: col1 - wavelength, col2 - GDD correspondong to col1, col3- wavelength, col4- reflecivity corresponding to col3
function propHD7203!(Eω, grid) #mutuable function for LunaPulse
    dat = readdlm(joinpath(Utils.datadir(), "\\Users\\kinca\\Documents\\ucf\\research\\lcls\\code\\61923\\mirrors\\HD7203.csv"), ','; skipstart=1)  #read data from file
    λR = dat[:, 1] * 1e-9 #assign 1st colou
    R = dat[:, 2] # reflectivity per mirror 
    λGDD = dat[:, 3] * 1e-9
    ω =  wlfreq.(λGDD)
    GDD = dat[:, 4] .* 1e-30 # GDD per mirror
    reflections=2
    λ0=1030e-9
    λmin=350e-9
    λmax=460e-9
    Fields.prop_mirror!(Eω, grid, reflections, λR, R, λGDD, GDD, λ0, λmin, λmax)
   Fields.prop_material!(Eω, grid, :MgF2, 1e-3, λ0) # 1 1-mm  window   
    _, Eωopt = Fields.optcomp_material(Eω, grid, :Air, λ0, -2, 2) # optimizing compression, last numbers are  min_thickness then max_thickness
    Eω .= Eωopt
end
function propHD7203(grid, Eω) #nonmutuable function for graphs
    Eωout = copy(Eω)
    propHD7203!(Eωout, grid)
    Eωout
end

#simulates pulse within soliton box (mainly used for pickoff mirrors)
function soliton_box(i,gas4, energy4, pressure4, infunc, propp) 
    #obtain pulse from the first fiber end via LunaPulse
    pulse_in_last = Pulses.LunaPulse(infunc; energy=energy4, propagator=propp) #input pulse from the 3rd stage
    #propagate through the second stage fiber to broaden bandwidth even more, with parameters listed above
    box[i]= prop_capillary(a3, flength4, gas4, pressure4; pulses=[pulse_in_last], λ0=λ0, trange=trange3, λlims=λlims_stg3, modes=modes)
end

#:'######:::'########:::::'###::::'########::'##::::'##::'######::
#'##... ##:: ##.... ##:::'## ##::: ##.... ##: ##:::: ##:'##... ##:
# ##:::..::: ##:::: ##::'##:. ##:: ##:::: ##: ##:::: ##: ##:::..::
# ##::'####: ########::'##:::. ##: ########:: #########:. ######::
# ##::: ##:: ##.. ##::: #########: ##.....::: ##.... ##::..... ##:
# ##::: ##:: ##::. ##:: ##.... ##: ##:::::::: ##:::: ##:'##::: ##:
#. ######::: ##:::. ##: ##:::: ##: ##:::::::: ##:::: ##:. ######::
#:......::::..:::::..::..:::::..::..:::::::::..:::::..:::......::

#graphs before compression 
function graphs_b4(func, range, bandpasss,trange) 
    Plotting.time_1D(func; modes=1,  FTL=FTL, trange=trange, bandpass=bandpasss) 		
        #^^plot of power as function of time for the mode specified 
         #can add bandpass= to look at pulse duration for certain wavelegnths
    Plotting.spec_1D(func; log10=false, modes=1,  λrange=range)
        #^^ plots SED as function of wavelength for each mode
    Plotting.stats(func)
        #^^ plots lots of info about each mode
    Plotting.energy(func; modes=1, bandpass=bandpasss)
        #^^ graphs the energy as a function of distance for given wavelength range
end

#graphs after compression 
function graphs_after(func, propp, range, bandpasss, trange) #where propp corresponds to prop1, or prop2 for compression
    Plotting.time_1D(func; modes=1, trange=trange, FTL=FTL, propagate=propp, bandpass=bandpasss) 		
        #^^plot of power as function of time for the mode specified 
        #can add bandpass= to look at pulse duration for certain wavelegnths
    Plotting.spec_1D(func; log10=false, modes=1, λrange=range)
        #^^ plots SED as function of wavelength for each mode
    Plotting.stats(func)
        #^^ plots lots of info about each mode
    Plotting.energy(func; modes=1, bandpass=bandpasss)
    #^^ graphs the energy as a function of distance for given wavelength range
end

#graphs the normalized SED vs wavelength, based on for loop from stg3
#some arrays may need the wavelegnth to be cut off later/sooner than the 1300
function graphs2_normSED_λ(func, j, a, pt1)

    if (a==1) #if statements to label legend on graphs
        ls=:dot
        time="5.29fs"
    elseif (a==2)
        ls=:solid
        time="7.37fs"
    elseif (a==3)
        ls=:dash
        time="9.21fs"
    elseif (a==4)
        ls=:dashdot
        time="10.74fs"
    else
        ls=:solid
    end
 
    #general plotting parameters
    xlims= (100, 500)
    xlabel="Wavelength (nm)"
    ylims= (0,1)
    ylabel= "Normalized Spectral energy density"
    title="Normalized SED vs λ with varying gas and pressure"
    y=0 #fills under the curve in solid color
    #plotting arrays/variables
    λ= Array{Any}(undef,100) #arbituary lengths
    Iλ= Array{Any}(undef,100)
    Iλ_norm=Array{Any}(undef,100)
    color= Array(["indigo", "blueviolet", "mediumslateblue", "blue", "cornflowerblue", "skyblue", "teal", "seagreen", "lime", "yellow", "gold", "orange", "orangered", "red"])

    #gets SED and λ then normalizes SED to graph with legend 
    λ[j], Iλ[j]=Processing.getIω(compressor_stg3[a, j], :λ,1) #get values of from the compressor function
    λ[j]=first(λ[j],1300) #filter out data points greater than window to normalize properly
    Iλ[j]=first(Iλ[j], 1300) #need the arrays to be the same size for plotting
    Iλ_norm[j]= (Iλ[j] / maximum(Iλ[j])) #normalize SED 
    plot!(pt1, λ[j]*1e9, Iλ_norm[j], fillrange=y, title=title, xlims=xlims, xlabel=xlabel, ylabel=ylabel, ylims=ylims, label="$(pressure3[a,j]) bar $(gas3[a,j]) $(time)", color="$(color[j])", linestyle=ls)
end


#graphs the normalized SED vs angular frequnecy, based on for loop from stg3
function graphs2_normSED_ω(func, j)
    
    #general plotting parameters
    plt.xlim(10e14, 30e14)
    plt.xlabel("Angular Frequency (rad/s)")
    plt.ylabel("Normalized Spectral energy density")
    plt.ylim(0,1)
    plt.title("Normalized SED vs Angular Frequency with varying gas and pressure")

    #plotting arrays/variables
    w= Array{Any}(undef,100) #arbituary lengths
    Iλ= Array{Any}(undef,100)
    Iλ_norm=Array{Any}(undef,100)
    color= Array(["indigo", "blueviolet", "mediumslateblue", "blue", "cornflowerblue", "skyblue", "teal", "seagreen", "lime", "yellow", "gold", "orange", "orangered", "red"])

    #gets SED and λ then normalizes SED to graph with legend 
    w[j], Iλ[j]=Processing.getIω(compressor_stg3[a, j], :ω,1) #get values of from the compressor function
    w[j]=first(w[j],1300) #filter out data points greater than window to normalize properly
    Iλ[j]=first(Iλ[j], 1300) #need the arrays to be the same size for plotting
    Iλ_norm[j]= (Iλ[j] / maximum(Iλ[j])) #normalize SED 
    plt.plot(w[j], Iλ_norm[j], label="$(pressure3[a,j]) bar $(gas3[a,j])", color="$(color[j])")
end

#graphs the normalized SED vs frequnecy, based on for loop from stg3
function graphs2_normSED_f(func, j)
    #general plotting parameters
    plt.xlim(100, 500)
    plt.xlabel("Frequency (THz)")
    plt.ylabel("Normalized Spectral energy density")
    plt.ylim(0,1)
    plt.title("Normalized SED vs Frequency with varying gas and pressure")

    #plotting arrays/variables
    f= Array{Any}(undef,100) #arbituary lengths
    Iλ= Array{Any}(undef,100)
    Iλ_norm=Array{Any}(undef,100)
    color= Array(["indigo", "blueviolet", "mediumslateblue", "blue", "cornflowerblue", "skyblue", "teal", "seagreen", "lime", "yellow", "gold", "orange", "orangered", "red"])

    #gets SED and λ then normalizes SED to graph with legend 
    f[j], Iλ[j]=Processing.getIω(func, :f,1) #get values of from the compressor function
    f[j]=first(f[j],1300) #filter out data points greater than window to normalize properly
    Iλ[j]=first(Iλ[j], 1300) #need the arrays to be the same size for plotting
    Iλ_norm[j]= (Iλ[j] / maximum(Iλ[j])) #normalize SED 
    plt.plot(f[j]*1e-12, Iλ_norm[j], label="$(pressure3[a,j]) bar $(gas3[a,j])", color="$(color[j])")
end

#graphs the normalized SED vs frequnecy, based on for loop from stg3
function graphs2_normSED_e(func,a, j)
        #general plotting parameters
    plt.xlim(0, 9)
    plt.xlabel("Energy (eV)")
    plt.ylabel("Normalized Spectral energy density")
    plt.ylim(0,1)
    plt.title("Normalized SED vs Energy with varying gas and pressure")

    #plotting arrays/variables
    f= Array{Any}(undef,100) #arbituary lengths
    Iλ= Array{Any}(undef,100)
    Iλ_norm=Array{Any}(undef,100)
    color= Array(["indigo", "blueviolet", "mediumslateblue", "blue", "cornflowerblue", "skyblue", "teal", "seagreen", "lime", "yellow", "gold", "orange", "orangered", "red"])

    #gets SED and λ then normalizes SED to graph with legend 
    f[j], Iλ[j]=Processing.getIω(func, :f,1) #get values of from the compressor function
    print(size(f[j]))
    f[j]=first(f[j],1300) #filter out data points greater than window to normalize properly
    Iλ[j]=first(Iλ[j], 1300) #need the arrays to be the same size for plotting
    Iλ_norm[j]= (Iλ[j] / maximum(Iλ[j])) #normalize SED 
    plt.plot(f[j]*4.14e-15, Iλ_norm[j], label="$(pressure3[a,j]) bar $(gas3[a,j])", color="$(color[j])")
    print(size(f[j]))

end

#graphs the normalized SED vs frequnecy, based on for loop from stg3
function graphs2_normSED_ezoom(func,a, j)
        #general plotting parameters
    plt.xlim(6, 9)
    plt.xlabel("Energy (eV)")
    plt.ylabel("Normalized Spectral energy density")
    plt.ylim(0,1)
    plt.title("Normalized SED vs Energy with varying gas and pressure")

    #plotting arrays/variables
    f= Array{Any}(undef,100) #arbituary lengths
    Iλ= Array{Any}(undef,100)
    Iλ_norm=Array{Any}(undef,100)
    color= Array(["indigo", "blueviolet", "mediumslateblue", "blue", "cornflowerblue", "skyblue", "teal", "seagreen", "lime", "yellow", "gold", "orange", "orangered", "red"])

    #gets SED and λ then normalizes SED to graph with legend 
    f[j], Iλ[j]=Processing.getIω(func, :f,1) #get values of from the compressor function
   # print(size(f[j]))
    f[j]=last(f[j],1000) #filter out data points greater than window to normalize properly
    Iλ[j]=last(Iλ[j], 1000) #need the arrays to be the same size for plotting
    Iλ_norm[j]= (Iλ[j] / maximum(Iλ[j])) #normalize SED 
    plt.plot(f[j]*4.14e-15, Iλ_norm[j], label="$(pressure3[a,j]) bar $(gas3[a,j])", color="$(color[j])")

end
# Out:
# graphs2_normSED_ezoom (generic function with 1 method)

# %%
#:::'##::::'######::'########:::::'######::'########::::'###:::::'######:::'########:
#:'####:::'##... ##:... ##..:::::'##... ##:... ##..::::'## ##:::'##... ##:: ##.....::
#:.. ##::: ##:::..::::: ##::::::: ##:::..::::: ##:::::'##:. ##:: ##:::..::: ##:::::::
#::: ##:::. ######::::: ##:::::::. ######::::: ##::::'##:::. ##: ##::'####: ######:::
#::: ##::::..... ##:::: ##::::::::..... ##:::: ##:::: #########: ##::: ##:: ##...::::
#::: ##:::'##::: ##:::: ##:::::::'##::: ##:::: ##:::: ##.... ##: ##::: ##:: ##:::::::
#:'######:. ######::::: ##:::::::. ######::::: ##:::: ##:::: ##:. ######::: ########:
#:......:::......::::::..:::::::::......::::::..:::::..:::::..:::......::::........::
λrange1=(900e-9,1100e-9) #bandwidth range for time domain graphs
bandpass=λrange1
trange=(-500e-15, 500e-15) #for time graphs

stg1(gas1, energy1, pressure1) #use predefined function to simulate pulse down first fiber
graphs_b4(compressor_stg1[1], λrange1, bandpass, trange) #plot pulse after first fiber before compression- function, predefined λrange in global variables  
graphs_after(compressor_stg1[1], prop1, λrange1, bandpass, trange) #plot pulse after compression - prop1 for first fiber, predefined λrange in global variables
# Out:
# [ Info: X+Y polarisation not required.
# [ Info: Freq limits 0.25 - 0.43 PHz
# [ Info: Samples needed: 2569.65, samples: 4096, δt = 389.16 as
# [ Info: Requested time window: 1000.0 fs, actual time window: 1594.0 fs
# [ Info: Grid: samples 2048 / 4096, ωmax 4.04e+15 / 8.07e+15
# [ Info: Using PPT ionisation rate.
# [ Info: Found cached PPT rate for 15.760834782784002 eV, 1030.0 nm
# [ Info: Using radial modal integral.
# [ Info: Found FFTW wisdom at C:\Users\kinca\.luna\FFTWcache_1threads
# [ Info: FFTW wisdom saved to C:\Users\kinca\.luna\FFTWcache_1threads
# [ Info: Found FFTW wisdom at C:\Users\kinca\.luna\FFTWcache_1threads
# [ Info: FFTW wisdom saved to C:\Users\kinca\.luna\FFTWcache_1threads
# [ Info: Starting propagation
# [ Info: Progress: 28.78 %, ETA: 00:00:12, stepsize 1.08e-02, err 0.16, repeated 0
# [ Info: Propagation finished in 7.791 seconds, 136 steps
# sys:1: UserWarning: The figure layout has changed to tight
# PyPlot.Figure(PyObject <Figure size 850x500 with 1 Axes>)
# PyPlot.Figure(PyObject <Figure size 850x500 with 1 Axes>)
# PyPlot.Figure(PyObject <Figure size 700x500 with 2 Axes>)
# PyPlot.Figure(PyObject <Figure size 850x500 with 1 Axes>)
# PyPlot.Figure(PyObject <Figure size 850x500 with 1 Axes>)
# PyPlot.Figure(PyObject <Figure size 1200x750 with 14 Axes>)
# PyPlot.Figure(PyObject <Figure size 800x750 with 12 Axes>)
# PyPlot.Figure(PyObject <Figure size 700x500 with 2 Axes>)
# PyPlot.Figure(PyObject <Figure size 700x500 with 2 Axes>)

# %%
#:'#######::'##::: ##:'########::::::'######::'########::::'###:::::'######:::'########:
#'##.... ##: ###:: ##: ##.... ##::::'##... ##:... ##..::::'## ##:::'##... ##:: ##.....::
#..::::: ##: ####: ##: ##:::: ##:::: ##:::..::::: ##:::::'##:. ##:: ##:::..::: ##:::::::
#:'#######:: ## ## ##: ##:::: ##::::. ######::::: ##::::'##:::. ##: ##::'####: ######:::
#'##:::::::: ##. ####: ##:::: ##:::::..... ##:::: ##:::: #########: ##::: ##:: ##...::::
# ##:::::::: ##:. ###: ##:::: ##::::'##::: ##:::: ##:::: ##.... ##: ##::: ##:: ##:::::::
# #########: ##::. ##: ########:::::. ######::::: ##:::: ##:::: ##:. ######::: ########:
#.........::..::::..::........:::::::......::::::..:::::..:::::..:::......::::........::
λrange2 = (600e-9, 1200e-9) #for frequency domain graphs
bandpass2=λrange2 #for time graphs

energy2= 1860e-6 #in joules
pressure2= .5 #in bar
stg2(a, gas2, energy2, pressure2) #simulate second fiber
graphs_b4(compressor_stg2[a], λrange2, bandpass2, trange) #plot pulse after second fiber before compression
graphs_after(compressor_stg2[a], prop2, λrange2, bandpass2, trange) #plot pulse after compression
# Out:
# [ Info: X+Y polarisation not required.
# [ Info: Freq limits 0.10 - 1.50 PHz
# [ Info: Samples needed: 4496.89, samples: 8192, δt = 111.19 as
# [ Info: Requested time window: 500.0 fs, actual time window: 910.9 fs
# [ Info: Grid: samples 4096 / 8192, ωmax 1.41e+16 / 2.83e+16
# [ Info: Using PPT ionisation rate.
# [ Info: Found cached PPT rate for 15.760834782784002 eV, 1030.0 nm
# [ Info: Using radial modal integral.
# [ Info: Found FFTW wisdom at C:\Users\kinca\.luna\FFTWcache_1threads
# [ Info: FFTW wisdom saved to C:\Users\kinca\.luna\FFTWcache_1threads
# [ Info: Found FFTW wisdom at C:\Users\kinca\.luna\FFTWcache_1threads
# [ Info: FFTW wisdom saved to C:\Users\kinca\.luna\FFTWcache_1threads
# [ Info: Starting propagation
# [ Info: Progress: 7.69 %, ETA: 00:01:01, stepsize 2.02e-03, err 0.23, repeated 0
# [ Info: Progress: 15.08 %, ETA: 00:00:57, stepsize 2.07e-03, err 0.20, repeated 0
# [ Info: Progress: 24.50 %, ETA: 00:00:46, stepsize 2.11e-03, err 0.22, repeated 0
# [ Info: Progress: 31.28 %, ETA: 00:00:44, stepsize 2.00e-03, err 0.20, repeated 0
# [ Info: Progress: 40.23 %, ETA: 00:00:37, stepsize 2.23e-03, err 0.23, repeated 0
# [ Info: Progress: 47.75 %, ETA: 00:00:33, stepsize 1.96e-03, err 0.21, repeated 0
# [ Info: Progress: 55.03 %, ETA: 00:00:28, stepsize 2.41e-03, err 0.21, repeated 0
# [ Info: Progress: 63.02 %, ETA: 00:00:23, stepsize 1.99e-03, err 0.22, repeated 0
# [ Info: Progress: 71.01 %, ETA: 00:00:18, stepsize 2.43e-03, err 0.21, repeated 0
# [ Info: Progress: 79.14 %, ETA: 00:00:13, stepsize 2.10e-03, err 0.22, repeated 0
# [ Info: Progress: 87.03 %, ETA: 00:00:08, stepsize 2.41e-03, err 0.20, repeated 0
# [ Info: Progress: 95.41 %, ETA: 00:00:02, stepsize 2.22e-03, err 0.22, repeated 0
# [ Info: Propagation finished in 1 minute, 3.543 seconds, 690 steps
# PyPlot.Figure(PyObject <Figure size 850x500 with 1 Axes>)
# PyPlot.Figure(PyObject <Figure size 850x500 with 1 Axes>)
# PyPlot.Figure(PyObject <Figure size 700x500 with 2 Axes>)
# PyPlot.Figure(PyObject <Figure size 850x500 with 1 Axes>)
# PyPlot.Figure(PyObject <Figure size 850x500 with 1 Axes>)
# PyPlot.Figure(PyObject <Figure size 1200x750 with 14 Axes>)
# PyPlot.Figure(PyObject <Figure size 800x750 with 12 Axes>)
# PyPlot.Figure(PyObject <Figure size 700x500 with 2 Axes>)
# PyPlot.Figure(PyObject <Figure size 700x500 with 2 Axes>)

# %%
# #:'#######::'########::'########::::::'######::'########::::'###:::::'######:::'########:
# #'##.... ##: ##.... ##: ##.... ##::::'##... ##:... ##..::::'## ##:::'##... ##:: ##.....::
# #..::::: ##: ##:::: ##: ##:::: ##:::: ##:::..::::: ##:::::'##:. ##:: ##:::..::: ##:::::::
# #:'#######:: ########:: ##:::: ##::::. ######::::: ##::::'##:::. ##: ##::'####: ######:::
# #:...... ##: ##.. ##::: ##:::: ##:::::..... ##:::: ##:::: #########: ##::: ##:: ##...::::
# #'##:::: ##: ##::. ##:: ##:::: ##::::'##::: ##:::: ##:::: ##.... ##: ##::: ##:: ##:::::::
# #. #######:: ##:::. ##: ########:::::. ######::::: ##:::: ##:::: ##:. ######::: ########:
# #:.......:::..:::::..::........:::::::......::::::..:::::..:::::..:::......::::........::
bandpass3= (100e-9, 1200e-9)#for the time duration plots in graphs_b4 and graphs_after, control what wavelengths are being measured; if not assigned then measures for whole spectra
λrange3= bandpass3 #for frequency domain graphs
trange=(-100e-15, 100e-15)
trange3=300e-15
#3rd stage parameters
gas3= :He #type of gas; He is Helium, Ne is Neon, Ar is Argon, Kr is Krypton
pressure3= 0.3#in bar
energy3=1675e-6 #override energy calculation from power, in joules

stg3(a, i, gas3, energy3, pressure3, compressor_stg2[a]) #simulate third fiber
graphs_b4(compressor_stg3[a, i], λrange3, bandpass3, trange) #plot pulse with full spectra
Plotting.prop_2D(compressor_stg3[a, i], :λ)
# Out:
# [ Info: X+Y polarisation not required.
# [ Info: Freq limits 0.21 - 3.00 PHz
# [ Info: Samples needed: 5396.26, samples: 8192, δt = 55.59 as
# [ Info: Requested time window: 300.0 fs, actual time window: 455.4 fs
# [ Info: Grid: samples 4096 / 8192, ωmax 2.83e+16 / 5.65e+16
# [ Info: Using PPT ionisation rate.
# [ Info: Found cached PPT rate for 24.588208407672 eV, 1030.0 nm
# [ Info: Using radial modal integral.
# [ Info: Found FFTW wisdom at C:\Users\kinca\.luna\FFTWcache_1threads
# [ Info: FFTW wisdom saved to C:\Users\kinca\.luna\FFTWcache_1threads
# [ Info: Found FFTW wisdom at C:\Users\kinca\.luna\FFTWcache_1threads
# [ Info: FFTW wisdom saved to C:\Users\kinca\.luna\FFTWcache_1threads
# [ Info: Starting propagation
# [ Info: Progress: 0.12 %, ETA: 01:10:54, stepsize 4.84e-05, err 0.27, repeated 2
# [ Info: Progress: 0.31 %, ETA: 00:55:41, stepsize 7.89e-05, err 0.66, repeated 2
# [ Info: Progress: 0.50 %, ETA: 00:51:14, stepsize 1.34e-04, err 0.63, repeated 2
# [ Info: Progress: 0.77 %, ETA: 00:44:41, stepsize 1.65e-04, err 0.85, repeated 2
# [ Info: Progress: 1.03 %, ETA: 00:41:33, stepsize 1.91e-04, err 0.38, repeated 2
# [ Info: Progress: 1.34 %, ETA: 00:37:58, stepsize 1.81e-04, err 0.49, repeated 2
# [ Info: Progress: 1.58 %, ETA: 00:37:41, stepsize 1.39e-04, err 0.09, repeated 4
# [ Info: Progress: 1.84 %, ETA: 00:36:41, stepsize 8.69e-05, err 0.12, repeated 4
# [ Info: Progress: 2.06 %, ETA: 00:36:43, stepsize 7.02e-05, err 0.51, repeated 4
# [ Info: Progress: 2.20 %, ETA: 00:38:07, stepsize 7.03e-05, err 0.19, repeated 4
# [ Info: Progress: 2.39 %, ETA: 00:38:30, stepsize 9.50e-05, err 0.31, repeated 4
# [ Info: Progress: 2.62 %, ETA: 00:38:17, stepsize 9.20e-05, err 0.51, repeated 4
# [ Info: Progress: 2.84 %, ETA: 00:38:07, stepsize 8.13e-05, err 0.44, repeated 4
# [ Info: Progress: 3.08 %, ETA: 00:37:41, stepsize 8.31e-05, err 0.13, repeated 6
# [ Info: Progress: 3.41 %, ETA: 00:36:27, stepsize 1.11e-04, err 0.09, repeated 6
# [ Info: Progress: 3.70 %, ETA: 00:35:41, stepsize 1.10e-04, err 0.07, repeated 6
# [ Info: Progress: 4.08 %, ETA: 00:34:15, stepsize 1.03e-04, err 0.28, repeated 6
# [ Info: Progress: 4.39 %, ETA: 00:33:32, stepsize 8.24e-05, err 0.21, repeated 6
# [ Info: Progress: 4.64 %, ETA: 00:33:24, stepsize 7.98e-05, err 0.11, repeated 6
# [ Info: Progress: 4.90 %, ETA: 00:33:14, stepsize 7.54e-05, err 0.11, repeated 7
# [ Info: Progress: 5.21 %, ETA: 00:32:42, stepsize 9.11e-05, err 0.26, repeated 7
# [ Info: Progress: 5.46 %, ETA: 00:32:33, stepsize 7.09e-05, err 0.04, repeated 7
# [ Info: Progress: 5.77 %, ETA: 00:32:08, stepsize 8.46e-05, err 0.39, repeated 7
# [ Info: Progress: 6.01 %, ETA: 00:32:05, stepsize 6.68e-05, err 0.16, repeated 7
# [ Info: Progress: 6.25 %, ETA: 00:32:02, stepsize 1.01e-04, err 0.10, repeated 7
# [ Info: Progress: 6.56 %, ETA: 00:31:37, stepsize 7.99e-05, err 0.10, repeated 7
# [ Info: Progress: 6.95 %, ETA: 00:30:51, stepsize 1.15e-04, err 0.29, repeated 7
# [ Info: Progress: 7.29 %, ETA: 00:30:22, stepsize 1.15e-04, err 0.13, repeated 7
# [ Info: Progress: 7.58 %, ETA: 00:30:07, stepsize 1.01e-04, err 0.02, repeated 7
# [ Info: Progress: 7.77 %, ETA: 00:30:23, stepsize 1.16e-04, err 0.11, repeated 7
# [ Info: Progress: 7.95 %, ETA: 00:30:37, stepsize 1.34e-04, err 0.40, repeated 7
# [ Info: Progress: 8.12 %, ETA: 00:30:54, stepsize 9.91e-05, err 0.13, repeated 7
# [ Info: Progress: 8.26 %, ETA: 00:31:33, stepsize 1.14e-04, err 0.11, repeated 7
# [ Info: Progress: 8.55 %, ETA: 00:31:16, stepsize 1.11e-04, err 0.26, repeated 7
# [ Info: Progress: 8.78 %, ETA: 00:31:14, stepsize 1.21e-04, err 0.20, repeated 7
# [ Info: Progress: 9.04 %, ETA: 00:31:08, stepsize 1.32e-04, err 0.55, repeated 7
# [ Info: Progress: 9.28 %, ETA: 00:31:04, stepsize 1.04e-04, err 0.38, repeated 8
# [ Info: Progress: 9.58 %, ETA: 00:30:48, stepsize 1.13e-04, err 0.12, repeated 8
# [ Info: Progress: 9.98 %, ETA: 00:30:10, stepsize 1.77e-04, err 0.11, repeated 8
# [ Info: Progress: 10.53 %, ETA: 00:29:09, stepsize 2.10e-04, err 0.93, repeated 8
# [ Info: Progress: 11.15 %, ETA: 00:28:00, stepsize 2.13e-04, err 0.64, repeated 9
# [ Info: Progress: 11.53 %, ETA: 00:27:39, stepsize 1.21e-04, err 0.23, repeated 9
# [ Info: Progress: 11.92 %, ETA: 00:27:13, stepsize 1.55e-04, err 0.42, repeated 9
# [ Info: Progress: 12.31 %, ETA: 00:26:51, stepsize 1.51e-04, err 0.05, repeated 9
# [ Info: Progress: 12.74 %, ETA: 00:26:23, stepsize 1.71e-04, err 0.10, repeated 9
# [ Info: Progress: 13.35 %, ETA: 00:25:33, stepsize 2.10e-04, err 0.17, repeated 9
# [ Info: Progress: 13.94 %, ETA: 00:24:50, stepsize 2.47e-04, err 0.14, repeated 9
# [ Info: Progress: 14.41 %, ETA: 00:24:24, stepsize 1.98e-04, err 0.56, repeated 10
# [ Info: Progress: 14.76 %, ETA: 00:24:14, stepsize 1.52e-04, err 0.05, repeated 11
# [ Info: Progress: 15.12 %, ETA: 00:24:02, stepsize 1.70e-04, err 0.09, repeated 11
# [ Info: Progress: 15.59 %, ETA: 00:23:38, stepsize 2.55e-04, err 0.38, repeated 11
# [ Info: Progress: 16.07 %, ETA: 00:23:14, stepsize 1.80e-04, err 0.31, repeated 11
# [ Info: Progress: 16.49 %, ETA: 00:22:57, stepsize 1.72e-04, err 0.20, repeated 11
# [ Info: Progress: 16.94 %, ETA: 00:22:39, stepsize 3.27e-04, err 0.30, repeated 11
# [ Info: Progress: 17.50 %, ETA: 00:22:11, stepsize 3.06e-04, err 1.19, repeated 11
# [ Info: Progress: 18.02 %, ETA: 00:21:48, stepsize 2.50e-04, err 0.03, repeated 13
# [ Info: Progress: 18.61 %, ETA: 00:21:19, stepsize 2.75e-04, err 0.30, repeated 13
# [ Info: Progress: 19.14 %, ETA: 00:20:57, stepsize 2.20e-04, err 0.21, repeated 13
# [ Info: Progress: 19.76 %, ETA: 00:20:28, stepsize 4.14e-04, err 0.13, repeated 13
# [ Info: Progress: 20.35 %, ETA: 00:20:04, stepsize 4.14e-04, err 0.11, repeated 13
# [ Info: Progress: 20.90 %, ETA: 00:19:44, stepsize 2.21e-04, err 1.18, repeated 14
# [ Info: Progress: 21.36 %, ETA: 00:19:32, stepsize 3.18e-04, err 0.10, repeated 15
# [ Info: Progress: 21.91 %, ETA: 00:19:12, stepsize 2.75e-04, err 0.55, repeated 15
# [ Info: Progress: 22.52 %, ETA: 00:18:50, stepsize 4.43e-04, err 0.13, repeated 15
# [ Info: Progress: 23.34 %, ETA: 00:18:15, stepsize 5.04e-04, err 0.10, repeated 15
# [ Info: Progress: 23.84 %, ETA: 00:18:01, stepsize 3.12e-04, err 0.22, repeated 15
# [ Info: Progress: 24.31 %, ETA: 00:17:50, stepsize 2.95e-04, err 0.39, repeated 15
# [ Info: Progress: 24.74 %, ETA: 00:17:41, stepsize 2.73e-04, err 0.27, repeated 15
# [ Info: Progress: 25.14 %, ETA: 00:17:34, stepsize 3.50e-04, err 0.26, repeated 15
# [ Info: Progress: 25.77 %, ETA: 00:17:14, stepsize 4.30e-04, err 0.23, repeated 15
# [ Info: Progress: 26.41 %, ETA: 00:16:54, stepsize 5.62e-04, err 0.36, repeated 15
# [ Info: Progress: 27.02 %, ETA: 00:16:37, stepsize 3.83e-04, err 0.22, repeated 15
# [ Info: Progress: 27.63 %, ETA: 00:16:21, stepsize 3.53e-04, err 0.10, repeated 15
# [ Info: Progress: 28.15 %, ETA: 00:16:09, stepsize 3.64e-04, err 0.15, repeated 15
# [ Info: Progress: 28.77 %, ETA: 00:15:54, stepsize 3.20e-04, err 0.11, repeated 15
# [ Info: Progress: 29.40 %, ETA: 00:15:37, stepsize 4.29e-04, err 0.44, repeated 15
# [ Info: Progress: 30.03 %, ETA: 00:15:21, stepsize 2.93e-04, err 0.03, repeated 15
# [ Info: Progress: 30.54 %, ETA: 00:15:12, stepsize 2.92e-04, err 0.59, repeated 15
# [ Info: Progress: 30.96 %, ETA: 00:15:05, stepsize 3.28e-04, err 0.17, repeated 15
# [ Info: Progress: 31.33 %, ETA: 00:15:02, stepsize 2.99e-04, err 0.08, repeated 15
# [ Info: Progress: 31.88 %, ETA: 00:14:51, stepsize 3.14e-04, err 0.43, repeated 15
# [ Info: Progress: 32.22 %, ETA: 00:14:48, stepsize 3.39e-04, err 0.24, repeated 15
# [ Info: Progress: 32.61 %, ETA: 00:14:43, stepsize 2.73e-04, err 0.03, repeated 15
# [ Info: Progress: 32.93 %, ETA: 00:14:41, stepsize 3.36e-04, err 0.30, repeated 15
# [ Info: Progress: 33.19 %, ETA: 00:14:41, stepsize 3.55e-04, err 0.59, repeated 15
# [ Info: Progress: 33.52 %, ETA: 00:14:38, stepsize 3.08e-04, err 0.15, repeated 15
# [ Info: Progress: 33.82 %, ETA: 00:14:37, stepsize 3.62e-04, err 0.66, repeated 16
# [ Info: Progress: 34.22 %, ETA: 00:14:31, stepsize 3.70e-04, err 0.08, repeated 16
# [ Info: Progress: 34.73 %, ETA: 00:14:21, stepsize 4.61e-04, err 0.22, repeated 16
# [ Info: Progress: 35.25 %, ETA: 00:14:12, stepsize 4.80e-04, err 0.29, repeated 16
# [ Info: Progress: 35.69 %, ETA: 00:14:05, stepsize 4.27e-04, err 0.44, repeated 16
# [ Info: Progress: 36.00 %, ETA: 00:14:03, stepsize 2.98e-04, err 0.14, repeated 17
# [ Info: Progress: 36.41 %, ETA: 00:13:57, stepsize 4.22e-04, err 0.35, repeated 17
# [ Info: Progress: 36.77 %, ETA: 00:13:54, stepsize 3.10e-04, err 0.33, repeated 17
# [ Info: Progress: 37.23 %, ETA: 00:13:46, stepsize 3.15e-04, err 0.06, repeated 17
# [ Info: Progress: 37.66 %, ETA: 00:13:40, stepsize 3.60e-04, err 0.06, repeated 17
# [ Info: Progress: 38.12 %, ETA: 00:13:32, stepsize 3.30e-04, err 0.10, repeated 17
# [ Info: Progress: 38.58 %, ETA: 00:13:25, stepsize 3.98e-04, err 0.41, repeated 17
# [ Info: Progress: 39.09 %, ETA: 00:13:16, stepsize 3.03e-04, err 0.20, repeated 17
# [ Info: Progress: 39.31 %, ETA: 00:13:16, stepsize 3.03e-04, err 0.34, repeated 18
# [ Info: Progress: 39.65 %, ETA: 00:13:13, stepsize 2.91e-04, err 0.06, repeated 19
# [ Info: Progress: 39.96 %, ETA: 00:13:10, stepsize 3.25e-04, err 0.61, repeated 20
# [ Info: Progress: 40.28 %, ETA: 00:13:07, stepsize 3.04e-04, err 0.54, repeated 20
# [ Info: Progress: 40.56 %, ETA: 00:13:06, stepsize 3.07e-04, err 0.46, repeated 20
# [ Info: Progress: 40.95 %, ETA: 00:13:00, stepsize 2.73e-04, err 0.64, repeated 20
# [ Info: Progress: 41.23 %, ETA: 00:12:59, stepsize 3.55e-04, err 0.92, repeated 20
# [ Info: Progress: 41.58 %, ETA: 00:12:55, stepsize 2.85e-04, err 0.24, repeated 20
# [ Info: Progress: 41.87 %, ETA: 00:12:53, stepsize 3.02e-04, err 0.17, repeated 21
# [ Info: Progress: 42.24 %, ETA: 00:12:48, stepsize 3.80e-04, err 0.30, repeated 21
# [ Info: Progress: 42.71 %, ETA: 00:12:40, stepsize 4.85e-04, err 0.39, repeated 21
# [ Info: Progress: 43.39 %, ETA: 00:12:27, stepsize 5.10e-04, err 0.10, repeated 21
# [ Info: Progress: 43.97 %, ETA: 00:12:16, stepsize 3.78e-04, err 0.19, repeated 22
# [ Info: Progress: 44.34 %, ETA: 00:12:12, stepsize 3.57e-04, err 0.70, repeated 23
# [ Info: Progress: 44.70 %, ETA: 00:12:07, stepsize 3.13e-04, err 0.03, repeated 23
# [ Info: Progress: 45.11 %, ETA: 00:12:02, stepsize 3.53e-04, err 0.23, repeated 23
# [ Info: Progress: 45.47 %, ETA: 00:11:58, stepsize 3.34e-04, err 1.11, repeated 23
# [ Info: Progress: 45.91 %, ETA: 00:11:51, stepsize 3.00e-04, err 0.14, repeated 24
# [ Info: Progress: 46.36 %, ETA: 00:11:45, stepsize 4.13e-04, err 0.34, repeated 24
# [ Info: Progress: 46.75 %, ETA: 00:11:40, stepsize 4.29e-04, err 0.18, repeated 24
# [ Info: Progress: 47.38 %, ETA: 00:11:28, stepsize 4.97e-04, err 0.39, repeated 24
# [ Info: Progress: 47.90 %, ETA: 00:11:19, stepsize 3.86e-04, err 0.26, repeated 26
# [ Info: Progress: 48.38 %, ETA: 00:11:13, stepsize 3.69e-04, err 0.14, repeated 26
# [ Info: Progress: 48.76 %, ETA: 00:11:08, stepsize 3.52e-04, err 0.27, repeated 26
# [ Info: Progress: 49.10 %, ETA: 00:11:05, stepsize 3.30e-04, err 0.30, repeated 27
# [ Info: Progress: 49.37 %, ETA: 00:11:03, stepsize 3.31e-04, err 0.17, repeated 28
# [ Info: Progress: 49.67 %, ETA: 00:11:00, stepsize 3.49e-04, err 0.34, repeated 29
# [ Info: Progress: 50.07 %, ETA: 00:10:55, stepsize 3.49e-04, err 0.47, repeated 29
# [ Info: Progress: 50.44 %, ETA: 00:10:50, stepsize 3.40e-04, err 0.30, repeated 29
# [ Info: Progress: 50.83 %, ETA: 00:10:45, stepsize 3.78e-04, err 0.16, repeated 29
# [ Info: Progress: 51.38 %, ETA: 00:10:36, stepsize 4.97e-04, err 0.11, repeated 29
# [ Info: Progress: 51.98 %, ETA: 00:10:26, stepsize 5.44e-04, err 0.15, repeated 30
# [ Info: Progress: 52.67 %, ETA: 00:10:13, stepsize 5.63e-04, err 0.10, repeated 31
# [ Info: Progress: 53.13 %, ETA: 00:10:06, stepsize 3.94e-04, err 0.07, repeated 32
# [ Info: Progress: 53.58 %, ETA: 00:10:00, stepsize 4.80e-04, err 0.06, repeated 32
# [ Info: Progress: 54.08 %, ETA: 00:09:52, stepsize 4.93e-04, err 0.41, repeated 32
# [ Info: Progress: 54.45 %, ETA: 00:09:48, stepsize 3.74e-04, err 0.42, repeated 33
# [ Info: Progress: 54.78 %, ETA: 00:09:44, stepsize 3.93e-04, err 0.59, repeated 33
# [ Info: Progress: 55.21 %, ETA: 00:09:38, stepsize 5.00e-04, err 0.12, repeated 33
# [ Info: Progress: 55.85 %, ETA: 00:09:28, stepsize 7.29e-04, err 0.35, repeated 33
# [ Info: Progress: 56.78 %, ETA: 00:09:11, stepsize 7.66e-04, err 0.14, repeated 33
# [ Info: Progress: 57.62 %, ETA: 00:08:56, stepsize 7.32e-04, err 0.32, repeated 33
# [ Info: Progress: 58.36 %, ETA: 00:08:44, stepsize 5.11e-04, err 0.41, repeated 34
# [ Info: Progress: 58.89 %, ETA: 00:08:36, stepsize 5.92e-04, err 0.22, repeated 34
# [ Info: Progress: 59.66 %, ETA: 00:08:23, stepsize 7.66e-04, err 0.08, repeated 34
# [ Info: Progress: 60.63 %, ETA: 00:08:07, stepsize 7.86e-04, err 0.21, repeated 34
# [ Info: Progress: 62.09 %, ETA: 00:07:41, stepsize 1.43e-03, err 0.14, repeated 34
# [ Info: Progress: 63.73 %, ETA: 00:07:13, stepsize 1.18e-03, err 0.15, repeated 35
# [ Info: Progress: 65.25 %, ETA: 00:06:47, stepsize 1.41e-03, err 0.10, repeated 35
# [ Info: Progress: 68.96 %, ETA: 00:05:47, stepsize 1.74e-03, err 0.10, repeated 35
# [ Info: Progress: 71.79 %, ETA: 00:05:05, stepsize 1.50e-03, err 0.09, repeated 35
# [ Info: Progress: 73.17 %, ETA: 00:04:46, stepsize 1.28e-03, err 0.16, repeated 37
# [ Info: Progress: 74.21 %, ETA: 00:04:33, stepsize 8.60e-04, err 0.46, repeated 39
# [ Info: Progress: 75.34 %, ETA: 00:04:19, stepsize 8.05e-04, err 0.20, repeated 39
# [ Info: Progress: 76.47 %, ETA: 00:04:05, stepsize 6.57e-04, err 0.18, repeated 39
# [ Info: Progress: 77.03 %, ETA: 00:03:59, stepsize 6.60e-04, err 0.23, repeated 40
# [ Info: Progress: 77.40 %, ETA: 00:03:56, stepsize 2.88e-04, err 0.32, repeated 42
# [ Info: Progress: 77.68 %, ETA: 00:03:53, stepsize 2.92e-04, err 1.08, repeated 43
# [ Info: Progress: 78.03 %, ETA: 00:03:50, stepsize 3.53e-04, err 0.04, repeated 44
# [ Info: Progress: 78.45 %, ETA: 00:03:46, stepsize 3.79e-04, err 0.31, repeated 44
# [ Info: Progress: 78.99 %, ETA: 00:03:40, stepsize 4.07e-04, err 0.16, repeated 44
# [ Info: Progress: 79.66 %, ETA: 00:03:33, stepsize 5.29e-04, err 0.50, repeated 44
# [ Info: Progress: 80.11 %, ETA: 00:03:28, stepsize 3.80e-04, err 0.05, repeated 45
# [ Info: Progress: 80.55 %, ETA: 00:03:24, stepsize 3.34e-04, err 0.48, repeated 46
# [ Info: Progress: 80.93 %, ETA: 00:03:20, stepsize 3.44e-04, err 0.64, repeated 46
# [ Info: Progress: 81.23 %, ETA: 00:03:17, stepsize 2.62e-04, err 0.13, repeated 47
# [ Info: Progress: 81.62 %, ETA: 00:03:14, stepsize 2.88e-04, err 0.36, repeated 47
# [ Info: Progress: 81.88 %, ETA: 00:03:11, stepsize 2.84e-04, err 0.20, repeated 47
# [ Info: Progress: 82.16 %, ETA: 00:03:09, stepsize 2.89e-04, err 0.23, repeated 48
# [ Info: Progress: 82.53 %, ETA: 00:03:05, stepsize 3.19e-04, err 0.22, repeated 48
# [ Info: Progress: 82.82 %, ETA: 00:03:03, stepsize 3.74e-04, err 0.21, repeated 48
# [ Info: Progress: 83.32 %, ETA: 00:02:57, stepsize 3.34e-04, err 0.77, repeated 48
# [ Info: Progress: 83.89 %, ETA: 00:02:51, stepsize 3.36e-04, err 0.25, repeated 48
# [ Info: Progress: 84.23 %, ETA: 00:02:48, stepsize 2.85e-04, err 0.63, repeated 49
# [ Info: Progress: 84.58 %, ETA: 00:02:44, stepsize 2.97e-04, err 0.49, repeated 49
# [ Info: Progress: 84.92 %, ETA: 00:02:41, stepsize 2.91e-04, err 0.14, repeated 49
# [ Info: Progress: 85.17 %, ETA: 00:02:39, stepsize 2.90e-04, err 0.26, repeated 49
# [ Info: Progress: 85.46 %, ETA: 00:02:36, stepsize 1.91e-04, err 0.08, repeated 52
# [ Info: Progress: 85.74 %, ETA: 00:02:33, stepsize 2.56e-04, err 0.12, repeated 52
# [ Info: Progress: 86.06 %, ETA: 00:02:30, stepsize 2.47e-04, err 0.15, repeated 52
# [ Info: Progress: 86.33 %, ETA: 00:02:28, stepsize 2.49e-04, err 0.68, repeated 52
# [ Info: Progress: 86.57 %, ETA: 00:02:25, stepsize 2.91e-04, err 0.21, repeated 52
# [ Info: Progress: 86.91 %, ETA: 00:02:22, stepsize 2.78e-04, err 0.27, repeated 52
# [ Info: Progress: 87.23 %, ETA: 00:02:19, stepsize 2.63e-04, err 0.03, repeated 52
# [ Info: Progress: 87.64 %, ETA: 00:02:14, stepsize 3.33e-04, err 0.13, repeated 52
# [ Info: Progress: 88.07 %, ETA: 00:02:10, stepsize 3.34e-04, err 0.38, repeated 53
# [ Info: Progress: 88.41 %, ETA: 00:02:06, stepsize 3.15e-04, err 0.22, repeated 54
# [ Info: Progress: 88.79 %, ETA: 00:02:02, stepsize 2.86e-04, err 0.16, repeated 54
# [ Info: Progress: 89.20 %, ETA: 00:01:58, stepsize 3.21e-04, err 0.31, repeated 54
# [ Info: Progress: 89.56 %, ETA: 00:01:54, stepsize 2.43e-04, err 0.13, repeated 54
# [ Info: Progress: 89.87 %, ETA: 00:01:51, stepsize 2.55e-04, err 0.74, repeated 54
# [ Info: Progress: 90.12 %, ETA: 00:01:48, stepsize 2.61e-04, err 0.33, repeated 55
# [ Info: Progress: 90.40 %, ETA: 00:01:45, stepsize 3.30e-04, err 0.07, repeated 55
# [ Info: Progress: 90.78 %, ETA: 00:01:41, stepsize 2.36e-04, err 0.35, repeated 55
# [ Info: Progress: 91.04 %, ETA: 00:01:39, stepsize 1.67e-04, err 0.15, repeated 56
# [ Info: Progress: 91.19 %, ETA: 00:01:37, stepsize 1.79e-04, err 0.12, repeated 57
# [ Info: Progress: 91.52 %, ETA: 00:01:34, stepsize 2.51e-04, err 0.50, repeated 57
# [ Info: Progress: 91.86 %, ETA: 00:01:30, stepsize 3.11e-04, err 0.79, repeated 57
# [ Info: Progress: 92.22 %, ETA: 00:01:26, stepsize 2.87e-04, err 0.23, repeated 57
# [ Info: Progress: 92.52 %, ETA: 00:01:23, stepsize 3.08e-04, err 0.16, repeated 58
# [ Info: Progress: 92.95 %, ETA: 00:01:18, stepsize 4.66e-04, err 0.26, repeated 58
# [ Info: Progress: 93.38 %, ETA: 00:01:13, stepsize 4.48e-04, err 0.20, repeated 58
# [ Info: Progress: 93.94 %, ETA: 00:01:07, stepsize 3.48e-04, err 0.72, repeated 58
# [ Info: Progress: 94.28 %, ETA: 00:01:03, stepsize 3.17e-04, err 0.18, repeated 58
# [ Info: Progress: 94.56 %, ETA: 00:01:00, stepsize 3.10e-04, err 0.62, repeated 58
# [ Info: Progress: 94.82 %, ETA: 00:00:58, stepsize 3.01e-04, err 0.05, repeated 58
# [ Info: Progress: 95.14 %, ETA: 00:00:54, stepsize 3.44e-04, err 0.38, repeated 58
# [ Info: Progress: 95.49 %, ETA: 00:00:50, stepsize 3.41e-04, err 0.44, repeated 58
# [ Info: Progress: 95.80 %, ETA: 00:00:47, stepsize 3.66e-04, err 0.41, repeated 58
# [ Info: Progress: 96.16 %, ETA: 00:00:43, stepsize 3.17e-04, err 0.19, repeated 59
# [ Info: Progress: 96.46 %, ETA: 00:00:40, stepsize 4.28e-04, err 0.06, repeated 59
# [ Info: Progress: 96.89 %, ETA: 00:00:35, stepsize 3.97e-04, err 0.12, repeated 59
# [ Info: Progress: 97.28 %, ETA: 00:00:30, stepsize 4.36e-04, err 0.17, repeated 59
# [ Info: Progress: 97.61 %, ETA: 00:00:27, stepsize 3.56e-04, err 0.46, repeated 59
# [ Info: Progress: 98.02 %, ETA: 00:00:22, stepsize 4.89e-04, err 0.40, repeated 59
# [ Info: Progress: 98.53 %, ETA: 00:00:16, stepsize 4.94e-04, err 0.06, repeated 59
# [ Info: Progress: 99.10 %, ETA: 00:00:10, stepsize 5.96e-04, err 0.50, repeated 59
# [ Info: Progress: 99.53 %, ETA: 00:00:05, stepsize 4.42e-04, err 0.20, repeated 59
# [ Info: Progress: 99.97 %, ETA: 00:00:00, stepsize 4.53e-04, err 0.15, repeated 59
# [ Info: Propagation finished in 18 minutes, 54.462 seconds, 3436 steps
# PyPlot.Figure(PyObject <Figure size 850x500 with 1 Axes>)
# PyPlot.Figure(PyObject <Figure size 850x500 with 1 Axes>)
# PyPlot.Figure(PyObject <Figure size 1200x750 with 7 Axes>)
# PyPlot.Figure(PyObject <Figure size 800x750 with 6 Axes>)
# PyPlot.Figure(PyObject <Figure size 700x500 with 2 Axes>)
# PyPlot.Figure(PyObject <Figure size 1200x400 with 4 Axes>)
# PyPlot.Figure(PyObject <Figure size 1200x400 with 4 Axes>)
# PyPlot.Figure(PyObject <Figure size 1200x400 with 4 Axes>)
# PyPlot.Figure(PyObject <Figure size 1200x400 with 4 Axes>)
# PyPlot.Figure(PyObject <Figure size 1200x400 with 4 Axes>)
# 5-element Vector{PyPlot.Figure}:
#  PyPlot.Figure(PyObject <Figure size 1200x400 with 4 Axes>)
#  PyPlot.Figure(PyObject <Figure size 1200x400 with 4 Axes>)
#  PyPlot.Figure(PyObject <Figure size 1200x400 with 4 Axes>)
#  PyPlot.Figure(PyObject <Figure size 1200x400 with 4 Axes>)
#  PyPlot.Figure(PyObject <Figure size 1200x400 with 4 Axes>)

# %%
#zoom in to specific areas from 3rd stage simulation and analysis through graphs

bandpass3= (100e-9, 200e-9)#for the time duration plots in graphs_b4 and graphs_after, control what wavelengths are being measured; if not assigned then measures for whole spectra
λrange3= bandpass3 #for frequency domain graphs
Plotting.time_1D(compressor_stg3[a, i]; modes=1, trange=(-300e-15, 300e-15), FTL=false, propagate=nothing, bandpass=bandpass3)
Plotting.spec_1D(compressor_stg3[a, i]; log10=false,  λrange=bandpass3) #graphs wavelength vs SED with wavlength limited by λrange
Plotting.energy(compressor_stg3[a, i], bandpass=bandpass3) #graphs energy and energy efficiency in area limited by bandpass
Plotting.stats(compressor_stg3[a, i]) #graphs lots of info for each mode, such as energy/peak_power/peak_intensity/FWHM/λzd/ionisation_fraction/electron_density vs distance, ,
# Out:
# PyPlot.Figure(PyObject <Figure size 850x500 with 1 Axes>)
# PyPlot.Figure(PyObject <Figure size 850x500 with 1 Axes>)
# PyPlot.Figure(PyObject <Figure size 700x500 with 2 Axes>)
# PyPlot.Figure(PyObject <Figure size 1200x750 with 7 Axes>)
# PyPlot.Figure(PyObject <Figure size 800x750 with 6 Axes>)
# 2-element Vector{PyPlot.Figure}:
#  PyPlot.Figure(PyObject <Figure size 1200x750 with 7 Axes>)
#  PyPlot.Figure(PyObject <Figure size 800x750 with 6 Axes>)

# %%
#use pickoff mirrors HD7203 or HD7201 in soliton box after 3rd stage to isolate RDW

#using the pickoff mirror hd7203
energy4=energy3*.6 # calculate energy out of third fiber for whole spectrum (60% loss is average)
gas4=:He #arbituary fiber gas, pressure, length for LunaPulse
pressure4=0.000000000001
flength4=.1

bandpass3= (100e-9, 450e-9)#for the time duration plots in graphs_b4 and graphs_after, control what wavelengths are being measured; if not assigned then measures for whole spectra
λrange3= bandpass3 #for frequency domain graphs

soliton_box(i,gas4, energy4, pressure4, compressor_stg3[a,i], propHD7203!) #simulate pulse through pickoff mirror speficied by last parameter
Plotting.time_1D(box[i]; modes=1, trange=(-300e-15, 300e-15), FTL=false, propagate=nothing, bandpass=bandpass3) #graph time domain of range bandpass3 after pickoff mirror
Plotting.spec_1D(box[i]; log10=false, modes=1, λrange=λrange3) #graphs frequency domain in rnage of bandpass3 after pickoff mirror
Plotting.energy(box[i]; modes=1, bandpass=bandpass3) #graphs energy in range of bandpass3 after pickoff mirror
# Out:
# [ Info: X+Y polarisation not required.
# [ Info: Freq limits 0.21 - 3.00 PHz
# [ Info: Samples needed: 8993.77, samples: 16384, δt = 55.59 as
# [ Info: Requested time window: 500.0 fs, actual time window: 910.9 fs
# [ Info: Grid: samples 8192 / 16384, ωmax 2.83e+16 / 5.65e+16
# [ Info: Using PPT ionisation rate.
# [ Info: Found cached PPT rate for 24.588208407672 eV, 1030.0 nm
# [ Info: Using radial modal integral.
# [ Info: Found FFTW wisdom at C:\Users\kinca\.luna\FFTWcache_1threads
# [ Info: FFTW wisdom saved to C:\Users\kinca\.luna\FFTWcache_1threads
# [ Info: Found FFTW wisdom at C:\Users\kinca\.luna\FFTWcache_1threads
# [ Info: FFTW wisdom saved to C:\Users\kinca\.luna\FFTWcache_1threads
# [ Info: Starting propagation
# [ Info: Propagation finished in 1.251 seconds, 5 steps
# PyPlot.Figure(PyObject <Figure size 850x500 with 1 Axes>)
# PyPlot.Figure(PyObject <Figure size 850x500 with 1 Axes>)
# PyPlot.Figure(PyObject <Figure size 700x500 with 2 Axes>)
# PyPlot.Figure(PyObject <Figure size 700x500 with 2 Axes>)

# %%
#overlay data on csv with simulated data for 3 modes

#get data from csv file
arr = np.loadtxt("\\Users\\kinca\\Documents\\ucf\\research\\lcls\\code\\61923\\overlay\\721\\363.csv", delimiter=",")

j=1
#graph prameters
plt.xlim(260, 400)
plt.xlabel("Wavelength (nm)")
plt.ylabel("Normalized Spectral energy density")
plt.ylim(0,1)
plt.title("Mode Matching Experimental RDW")
color= Array(["indigo", "blueviolet", "mediumslateblue", "blue", "cornflowerblue", "skyblue", "teal", "seagreen", "lime", "yellow", "gold", "orange", "orangered", "red"])
#plotting arrays/variables
λ= Array{Any}(undef,100) #arbituary lengths
Iλ= Array{Any}(undef,100)
Iλ_norm1=Array{Any}(undef,100)
    

λ1, Iλ=Processing.getIω(compressor_stg3[a, j], :λ,1) #get values of from the compressor function
Iλ1=Iλ[:,1,1] #first mode
Iλ2=Iλ[:,2,1] #second mode
Iλ3=Iλ[:,3,1] #third mode
λ2=λ1
λ3=λ1

 
c=1300 #variable to limit the range of plotted, for cleaniness/proper normalization in the window
b=1300
e=1500

arr_norm= (arr[:,2] / maximum(arr[:,2])) #normalize SED from imported csv

λ1=first(λ1,c) #filter out data points greater than window to normalize properly
#λ1=last(λ1,100) #filter out data points greater than window to normalize properly
Iλ1=first(Iλ1, c) #need the arrays to be the same size for plotting
#Iλ1=last(Iλ1, 100) #need the arrays to be the same size for plotting
Iλ_norm1= (Iλ1 / maximum(Iλ1)) #normalize SED 
    
λ2=first(λ2,b) #filter out data points greater than window to normalize properly
#λ2=last(λ2,500) #filter out data points greater than window to normalize properly
Iλ2=first(Iλ2, b) #need the arrays to be the same size for plotting
#Iλ2=last(Iλ2, 500) #need the arrays to be the same size for plotting
Iλ_norm2= (Iλ2 / maximum(Iλ2)) #normalize SED 

λ3=first(λ3,e) #filter out data points greater than window to normalize properly
#λ3=last(λ3,e) #filter out data points greater than window to normalize properly
Iλ3=first(Iλ3, e) #need the arrays to be the same size for plotting
#Iλ3=last(Iλ3, e) #need the arrays to be the same size for plotting
Iλ_norm3= (Iλ3 / maximum(Iλ3)) #normalize SED 


#plot the data
plt.plot(λ1*1e9, Iλ_norm1[:,1], label="HE11 mode", color="$(color[j])")
plt.plot(λ2*1e9, Iλ_norm2[:,1], label="HE12 mode", color="$(color[j+1])")
#plt.plot(λ3*1e9, Iλ_norm3[:,1], label="Mode HE13", color="$(color[j+2])")
plt.plot( arr[:,1], arr_norm[:,1], label="experimental", color=:cornflowerblue) #plot the imported data
plt.legend( loc="best") #moves legend to best location
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x000001BEDD3F31C0>

# %%
#graph simulated data for wavelegnth domain

#graph parameters
plt.xlim(800,1200)
plt.xlabel("Wavelength (nm)", fontsize=12)
plt.ylabel("Spectral energy density", fontsize=12)
#plt.ylim(0,45)
#plt.title("SED vs Wavelength for varying modes for $(gas3) at $(pressure3) bar $(energy3*1e6)uJ")
color= Array(["indigo", "blueviolet", "mediumslateblue", "blue", "cornflowerblue", "skyblue", "teal", "seagreen", "lime", "yellow", "gold", "orange", "orangered", "red"])


λ2, Iλ2=Processing.getIω(compressor_stg2[a], :λ,flength2, specrange=(100e-9,1200e-9), resolution=10e-9) #get values of from the compressor function
Iλ2=dropdims(sum(Iλ2[:,:,end], dims=2), dims=2) #sum the dimensions (modes) and drop so arrays are the same size


plt.plot(λ2*1e9, Iλ2, color="$(color[2])") #plot data
plt.legend( loc="best", fontsize=15) #moves legend to best location, increases size
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x000001BEDD3BB730>

# %%
#graph simulated data for time domain  

#graph parameters
plt.xlim(-20,100)
plt.xlabel("Time (fs)", fontsize=12)
plt.ylabel("Power (GW)", fontsize=12)
plt.ylim(0,6)
#plt.title("SED vs Wavelength for varying modes for $(gas3) at $(pressure3) bar $(energy3*1e6)uJ")
color= Array(["indigo", "blueviolet", "mediumslateblue", "blue", "cornflowerblue", "skyblue", "teal", "seagreen", "lime", "yellow", "gold", "orange", "orangered", "red"])

t, Et=Processing.getEt(compressor_stg3[a,i], flength3,  bandpass=(150e-9,170e-9), FTL=false, propagate=nothing) #get values of from the compressor function in time domain
Et=abs2.(Et)#only nonnegative values of power
Et=dropdims(sum(Et, dims=2), dims=2) #sum the dimensions (modes) and drop so arrays are the same size

plt.plot(t*1e15, Et*1e-6,label="20.8 fs", color="$(color[2])") #plot data
plt.legend( loc="best", fontsize=12) #moves legend to outside the graph and populates with gas and pressure
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x000001BEDA667F40>
